# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from scipy.interpolate import interp1d
from tqdm import tqdm
warnings.filterwarnings('ignore', category=RuntimeWarning)
warnings.filterwarnings('ignore')

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
from tqdm import tqdm

def sliding_window_segmentation(data, window_size, step_size, mmsi):
    segments = []
    for start in range(0, len(data) - window_size + 1, step_size):
        window = data.iloc[start:start + window_size].copy()
        window['MMSI'] = mmsi
        segments.append(window)
    return segments

def lat_lon_range(df_file):
    min_lat, max_lat = df_file['LAT'].min(), df_file['LAT'].max()
    min_lon, max_lon = df_file['LON'].min(), df_file['LON'].max()
    min_lat, max_lat, min_lon, max_lon = (
        int(np.floor(min_lat)),
        int(np.ceil(max_lat)),
        int(np.floor(min_lon)),
        int(np.ceil(max_lon)),
    )
    return min_lat, max_lat, min_lon, max_lon

def prepare_ais_data_without_interpolation(
    data, bounding_box, window_size, step_size
):
    min_lat, max_lat, min_lon, max_lon = bounding_box

    filtered_data = data[
        (data['LAT'] >= min_lat) & (data['LAT'] <= max_lat) &
        (data['LON'] >= min_lon) & (data['LON'] <= max_lon)
    ]

    grouped = filtered_data.groupby('MMSI')
    segments = []
    segment_id = 0

    for mmsi, group in tqdm(grouped, desc="Processing MMSI", unit="MMSI"):
        group = group.sort_values(by='BaseDateTime')
        group['BaseDateTime'] = pd.to_datetime(group['BaseDateTime'])

        # Directly use the existing data without interpolation
        resampled_traj = group[['BaseDateTime', 'LAT', 'LON', 'SOG', 'COG']].copy()

        trajectory_segments = sliding_window_segmentation(resampled_traj, window_size, step_size, mmsi)

        for segment in trajectory_segments:
            segment['SegmentID'] = segment_id
            segments.append(segment)
            segment_id += 1

    combined_df = pd.concat(segments, ignore_index=True)
    return combined_df

# Example usage
if __name__ == "__main__":
    df = pd.read_csv("/content/modified_ais_data.csv")[:100000]

    # Define bounding box from the dataset
    min_lat, max_lat, min_lon, max_lon = lat_lon_range(df)
    bounding_box = (min_lat, max_lat, min_lon, max_lon)

    window_size = 10
    step_size = 5

    segmented_trajectories_df = prepare_ais_data_without_interpolation(
        df, bounding_box, window_size, step_size
    )

    segmented_trajectories_df.to_csv("segmented_trajectories.csv", index=False)
# Out:
# Processing MMSI: 100%|██████████| 3093/3093 [00:20<00:00, 150.31MMSI/s]

# %% [markdown]
# ### calculate duration

# %%
def calculate_durations(group):
    # Ensure BaseDateTime is a datetime type
    group['BaseDateTime'] = pd.to_datetime(group['BaseDateTime'])
    # Calculate the duration between consecutive points in seconds
    group['duration_seconds'] = group['BaseDateTime'].diff().dt.total_seconds()
    return group

# %%
segmented_trajectories_df = segmented_trajectories_df.sort_values(by=['BaseDateTime'])
segmented_trajectories_df = segmented_trajectories_df.groupby("MMSI", group_keys=False).apply(calculate_durations)
segmented_trajectories_df = segmented_trajectories_df.reset_index(drop=True)
segmented_trajectories_df.head()
# Out:
#   BaseDateTime       LAT        LON  SOG    COG       MMSI  SegmentID  \
# 0   2022-03-31  32.65303 -117.12239  1.7  166.4  366764730       4891
# 1   2022-03-31  34.36573 -121.77418  7.9  278.0  356909000       4471
# 2   2022-03-31  48.47441 -125.41904  1.0  115.0  357175000       4478
# 3   2022-03-31  29.74757  -95.11144  0.0  238.0  367141680       6735
# 4   2022-03-31  24.08663  -82.27491  9.4   57.0  319874000       3544
#
#    duration_seconds
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
segmented_trajectories_df.isna().sum()
# Out:
# BaseDateTime           0
# LAT                    0
# LON                    0
# SOG                    0
# COG                    0
# MMSI                   0
# SegmentID              0
# duration_seconds    2750
# dtype: int64

# %%
segmented_trajectories_df.shape
# Out:
# (158270, 8)

# %%
segmented_trajectories_df.fillna(0,inplace=True)

# %%
segmented_trajectories_df.isna().sum()
# Out:
# BaseDateTime        0
# LAT                 0
# LON                 0
# SOG                 0
# COG                 0
# MMSI                0
# SegmentID           0
# duration_seconds    0
# dtype: int64

# %% [markdown]
# ### calculate x,y,z

# %%
import math

def lat_lon_to_cartesian(lat, lon, R=6371):
    lat_rad = math.radians(lat)
    lon_rad = math.radians(lon)
    x = R * math.cos(lat_rad) * math.cos(lon_rad)
    y = R * math.cos(lat_rad) * math.sin(lon_rad)
    z = R * math.sin(lat_rad)
    return x, y, z

def cartesian_to_lat_lon(x, y, z, R=6371):
    lon = math.degrees(math.atan2(y, x))
    lat = math.degrees(math.asin(z / R))
    return lat, lon

# %%
segmented_trajectories_df[['x', 'y', 'z']] = segmented_trajectories_df.apply(lambda row: pd.Series(lat_lon_to_cartesian(row['LAT'], row['LON'])), axis=1)
segmented_trajectories_df.head()
# Out:
#   BaseDateTime       LAT        LON  SOG    COG       MMSI  SegmentID  \
# 0   2022-03-31  32.65303 -117.12239  1.7  166.4  366764730       4891
# 1   2022-03-31  34.36573 -121.77418  7.9  278.0  356909000       4471
# 2   2022-03-31  48.47441 -125.41904  1.0  115.0  357175000       4478
# 3   2022-03-31  29.74757  -95.11144  0.0  238.0  367141680       6735
# 4   2022-03-31  24.08663  -82.27491  9.4   57.0  319874000       3544
#
#    duration_seconds            x            y            z
# 0               0.0 -2445.447444 -4774.221861  3437.474862
# 1               0.0 -2769.219752 -4470.791605  3596.259916
# 2               0.0 -2447.844023 -3442.028194  4769.710950
# 3               0.0  -492.812521 -5509.431869  3161.160752
# 4               0.0   781.824216 -5763.487453  2600.116203

# %% [markdown]
# ### calculate distance

# %%
import numpy as np
def haversine(lat1, lon1, lat2, lon2, R=6371):
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat / 2) ** 2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2) ** 2
    c = 2 * np.arcsin(np.sqrt(a))
    return R * c

def calculate_distances(group):
    group = group.sort_values(by="BaseDateTime")
    group["next_lat"] = group["LAT"].shift(-1)
    group["next_long"] = group["LON"].shift(-1)
    group["distance_km"] = group.apply(
        lambda row: haversine(row["LAT"], row["LON"], row["next_lat"], row["next_long"])
        if not np.isnan(row["next_lat"])
        else 0,
        axis=1,
    )
    return group.drop(columns=["next_lat", "next_long"])

# %%
segmented_trajectories_df = segmented_trajectories_df.groupby("MMSI").apply(calculate_distances).reset_index(drop=True)
segmented_trajectories_df.head()
# Out:
#          BaseDateTime       LAT       LON  SOG    COG  MMSI  SegmentID  \
# 0 2022-03-31 00:02:32  27.35372 -94.62546  0.4  228.6   111          0
# 1 2022-03-31 00:05:35  27.35372 -94.62550  0.6  219.8   111          0
# 2 2022-03-31 00:08:34  27.35377 -94.62556  0.2  221.7   111          0
# 3 2022-03-31 00:11:31  27.35380 -94.62557  0.3  105.0   111          0
# 4 2022-03-31 00:14:33  27.35365 -94.62542  0.3  173.4   111          0
#
#    duration_seconds           x            y            z  distance_km
# 0               0.0 -456.323030 -5640.208831  2927.363085     0.003950
# 1             183.0 -456.326968 -5640.208513  2927.363085     0.008126
# 2             179.0 -456.332668 -5640.205489  2927.368023     0.003479
# 3             177.0 -456.333529 -5640.203881  2927.370986     0.022308
# 4             182.0 -456.319381 -5640.212715  2927.356172     0.002224

# %% [markdown]
# ### Convert SOG to meters per second

# %%
segmented_trajectories_df['sog_to_meters_per_second'] =  segmented_trajectories_df.apply(lambda row: row['SOG'] * 0.514444, axis=1)
segmented_trajectories_df.head()
# Out:
#          BaseDateTime       LAT       LON  SOG    COG  MMSI  SegmentID  \
# 0 2022-03-31 00:02:32  27.35372 -94.62546  0.4  228.6   111          0
# 1 2022-03-31 00:05:35  27.35372 -94.62550  0.6  219.8   111          0
# 2 2022-03-31 00:08:34  27.35377 -94.62556  0.2  221.7   111          0
# 3 2022-03-31 00:11:31  27.35380 -94.62557  0.3  105.0   111          0
# 4 2022-03-31 00:14:33  27.35365 -94.62542  0.3  173.4   111          0
#
#    duration_seconds           x            y            z  distance_km  \
# 0               0.0 -456.323030 -5640.208831  2927.363085     0.003950
# 1             183.0 -456.326968 -5640.208513  2927.363085     0.008126
# 2             179.0 -456.332668 -5640.205489  2927.368023     0.003479
# 3             177.0 -456.333529 -5640.203881  2927.370986     0.022308
# 4             182.0 -456.319381 -5640.212715  2927.356172     0.002224
#
#    sog_to_meters_per_second
# 0                  0.205778
# 1                  0.308666
# 2                  0.102889
# 3                  0.154333
# 4                  0.154333

# %% [markdown]
# ### Convert COG to radians

# %%
segmented_trajectories_df['cog_to_radians'] = segmented_trajectories_df.apply(lambda row: np.radians(row['COG']) , axis=1)
segmented_trajectories_df.head()
# Out:
#          BaseDateTime       LAT       LON  SOG    COG  MMSI  SegmentID  \
# 0 2022-03-31 00:02:32  27.35372 -94.62546  0.4  228.6   111          0
# 1 2022-03-31 00:05:35  27.35372 -94.62550  0.6  219.8   111          0
# 2 2022-03-31 00:08:34  27.35377 -94.62556  0.2  221.7   111          0
# 3 2022-03-31 00:11:31  27.35380 -94.62557  0.3  105.0   111          0
# 4 2022-03-31 00:14:33  27.35365 -94.62542  0.3  173.4   111          0
#
#    duration_seconds           x            y            z  distance_km  \
# 0               0.0 -456.323030 -5640.208831  2927.363085     0.003950
# 1             183.0 -456.326968 -5640.208513  2927.363085     0.008126
# 2             179.0 -456.332668 -5640.205489  2927.368023     0.003479
# 3             177.0 -456.333529 -5640.203881  2927.370986     0.022308
# 4             182.0 -456.319381 -5640.212715  2927.356172     0.002224
#
#    sog_to_meters_per_second  cog_to_radians
# 0                  0.205778        3.989823
# 1                  0.308666        3.836234
# 2                  0.102889        3.869395
# 3                  0.154333        1.832596
# 4                  0.154333        3.026401

# %%
segmented_trajectories_df = segmented_trajectories_df[['x','y','z','duration_seconds', 'distance_km', 'sog_to_meters_per_second', 'cog_to_radians','SegmentID']]
segmented_trajectories_df.head()
# Out:
#             x            y            z  duration_seconds  distance_km  \
# 0 -456.323030 -5640.208831  2927.363085               0.0     0.003950
# 1 -456.326968 -5640.208513  2927.363085             183.0     0.008126
# 2 -456.332668 -5640.205489  2927.368023             179.0     0.003479
# 3 -456.333529 -5640.203881  2927.370986             177.0     0.022308
# 4 -456.319381 -5640.212715  2927.356172             182.0     0.002224
#
#    sog_to_meters_per_second  cog_to_radians  SegmentID
# 0                  0.205778        3.989823          0
# 1                  0.308666        3.836234          0
# 2                  0.102889        3.869395          0
# 3                  0.154333        1.832596          0
# 4                  0.154333        3.026401          0

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tqdm import tqdm


# Filter segments with insufficient rows
def filter_short_segments(data, window_size, prediction_horizon, group_col='SegmentID'):
    min_required_rows = window_size + prediction_horizon
    filtered_data = data.groupby(group_col).filter(lambda x: len(x) >= min_required_rows)
    print(f"Filtered data contains {len(filtered_data)} rows after removing short segments.")
    return filtered_data


# Prepare sequences with temporal features and SegmentID
def prepare_sequences(data, window_size, prediction_horizon,
                      group_col='SegmentID', time_col='BaseDateTime'):
    sequences = []
    unique_segments = sorted(data[group_col].unique())

    for segment in tqdm(unique_segments, desc="Processing Segments", unit="segment"):
        segment_data = data[data[group_col] == segment].reset_index(drop=True)
        num_rows = len(segment_data)
        # print(f"Segment {segment} has {num_rows} rows.")

        if num_rows < window_size + prediction_horizon:
            # print(f"Skipping segment {segment}: Not enough rows.")
            continue

        for start in range(num_rows - window_size - prediction_horizon + 1):
            x_window = segment_data.iloc[start:start+window_size]
            y_window = segment_data.iloc[start+window_size:start+window_size+prediction_horizon]
            sequences.append({
                'X': {
                    'x': x_window['x'].tolist(),
                    'y': x_window['y'].tolist(),
                    'z': x_window['z'].tolist(),
                    'duration_seconds': x_window['duration_seconds'].tolist(),
                    'distance_km': x_window['distance_km'].tolist(),
                    'sog_to_meters_per_second': x_window['sog_to_meters_per_second'].tolist(),
                    'cog_to_radians': x_window['cog_to_radians'].tolist(),
                    'SegmentID': x_window['SegmentID'].tolist(),
                },
                'Y': {
                   'x': x_window['x'].tolist(),
                    'y': x_window['y'].tolist(),
                    'z': x_window['z'].tolist(),
                    'duration_seconds': x_window['duration_seconds'].tolist(),
                    'distance_km': x_window['distance_km'].tolist(),
                    'sog_to_meters_per_second': x_window['sog_to_meters_per_second'].tolist(),
                    'cog_to_radians': x_window['cog_to_radians'].tolist(),
                    'SegmentID': x_window['SegmentID'].tolist(),
                }
            })
    return sequences


# Split data into train/val/test
def split_train_val_test(data, test_size=0.2, val_size=0.2):
    train_data, temp_data = train_test_split(data, test_size=test_size + val_size, random_state=42, shuffle=True)
    val_data, test_data = train_test_split(temp_data, test_size=test_size / (test_size + val_size), random_state=42, shuffle=True)
    return train_data, val_data, test_data


# Data preparation pipeline without scaling
def prepare_data_pipeline_no_scaling(data, window_size, prediction_horizon,
                                     test_size=0.2, val_size=0.2):
    # Filter short segments
    print("Filtering short segments...")
    data = filter_short_segments(data, window_size, prediction_horizon)

    # Split data
    print("Splitting data into train, validation, and test sets...")
    train_data, val_data, test_data = split_train_val_test(data, test_size, val_size)

    # Prepare sequences
    print("Preparing training sequences...")
    train_sequences = prepare_sequences(train_data, window_size, prediction_horizon)

    print("Preparing validation sequences...")
    val_sequences = prepare_sequences(val_data, window_size, prediction_horizon)

    print("Preparing test sequences...")
    test_sequences = prepare_sequences(test_data, window_size, prediction_horizon)

    return train_sequences, val_sequences, test_sequences

# Parameters
window_size = 5
prediction_horizon = 2
test_size = 0.2
val_size = 0.32


# Prepare data
train_sequences, val_sequences, test_sequences = prepare_data_pipeline_no_scaling(
    segmented_trajectories_df, window_size, prediction_horizon, test_size, val_size
)

print(f"Number of training sequences: {len(train_sequences)}")
print(f"Number of validation sequences: {len(val_sequences)}")
print(f"Number of test sequences: {len(test_sequences)}")
# Out:
# Filtering short segments...
# Filtered data contains 158270 rows after removing short segments.
# Splitting data into train, validation, and test sets...
# Preparing training sequences...
# Processing Segments: 100%|██████████| 15793/15793 [00:12<00:00, 1259.92segment/s]
# Preparing validation sequences...
# Processing Segments: 100%|██████████| 15486/15486 [00:10<00:00, 1510.86segment/s]
# Preparing test sequences...
# Processing Segments: 100%|██████████| 14065/14065 [00:10<00:00, 1334.58segment/s]
# Number of training sequences: 3084
# Number of validation sequences: 287
# Number of test sequences: 14

# %%
import numpy as np

def format_sequences(sequences, input_features, output_features, predicted_seq_len):
    """
    Format sequences for Seq2Seq model.

    Parameters:
    - sequences: List of dictionaries with 'X' and 'Y'.
    - input_features: List of feature names for inputs.
    - output_features: List of feature names for outputs.
    - predicted_seq_len: Length of the predicted sequence.

    Returns:
    - encoder_inputs: NumPy array of shape (num_sequences, input_seq_len, num_features).
    - decoder_inputs: NumPy array of shape (num_sequences, output_seq_len, num_features).
    - targets: NumPy array of shape (num_sequences, output_seq_len, num_targets).
    """
    encoder_inputs = []
    decoder_inputs = []
    targets = []

    for seq in sequences:
        # Extract input features for encoder
        encoder_input = np.array([seq['X'][feature] for feature in input_features]).T
        encoder_inputs.append(encoder_input)

        # Extract Y data for decoder inputs and targets
        y_data = np.array([seq['Y'][feature] for feature in input_features]).T  # Use input features for decoder inputs
        target_data = np.array([seq['Y'][feature] for feature in output_features]).T  # Use output features for targets

        # Ensure y_data has at least predicted_seq_len timesteps
        y_data = y_data[:predicted_seq_len, :] if len(y_data) >= predicted_seq_len else np.pad(
            y_data, ((0, predicted_seq_len - len(y_data)), (0, 0)), mode='constant'
        )

        target_data = target_data[:predicted_seq_len, :] if len(target_data) >= predicted_seq_len else np.pad(
            target_data, ((0, predicted_seq_len - len(target_data)), (0, 0)), mode='constant'
        )

        # Initialize decoder input and fill with previous steps
        decoder_input = np.zeros((predicted_seq_len, len(input_features)))
        decoder_input[:min(len(y_data) - 1, predicted_seq_len - 1), :] = y_data[:min(len(y_data) - 1, predicted_seq_len - 1), :]

        decoder_inputs.append(decoder_input)
        targets.append(target_data)

    return (
        np.array(encoder_inputs),
        np.array(decoder_inputs),
        np.array(targets)
    )


# Define the features for input and output
input_features = ['x', 'y', 'z', 'duration_seconds', 'distance_km',
                  'sog_to_meters_per_second', 'cog_to_radians']

output_features = ['x', 'y', 'z', 'duration_seconds',
                  'sog_to_meters_per_second', 'cog_to_radians']

predicted_seq_len = 2

# Format sequences for training, validation, and testing
train_enc_inputs, train_dec_inputs, train_targets = format_sequences(train_sequences, input_features, output_features, predicted_seq_len)
val_enc_inputs, val_dec_inputs, val_targets = format_sequences(val_sequences, input_features, output_features, predicted_seq_len)
test_enc_inputs, test_dec_inputs, test_targets = format_sequences(test_sequences, input_features, output_features, predicted_seq_len)

# Print the shapes to verify
print("Training data shapes:")
print(f"Encoder inputs: {train_enc_inputs.shape}, Decoder inputs: {train_dec_inputs.shape}, Targets: {train_targets.shape}")

# Check for NaN or Inf in your data
print("Checking training data for NaN or Inf...")
print(np.isnan(train_enc_inputs).any(), np.isinf(train_enc_inputs).any())
print(np.isnan(train_dec_inputs).any(), np.isinf(train_dec_inputs).any())
print(np.isnan(train_targets).any(), np.isinf(train_targets).any())
# Out:
# Training data shapes:
# Encoder inputs: (3084, 5, 7), Decoder inputs: (3084, 2, 7), Targets: (3084, 2, 6)
# Checking training data for NaN or Inf...
# False False
# False False
# False False

# %%
import tensorflow as tf
from tensorflow.keras.layers import (
    Input, LSTM, Dense, Concatenate, Dropout, MultiHeadAttention,
    Add, LayerNormalization, RepeatVector, Lambda, Conv1D, Bidirectional
)
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

def create_advanced_probabilistic_seq2seq(input_seq_len, output_seq_len, input_dim, output_dim, latent_dim):
    """
    Enhanced Probabilistic Seq2Seq Model for Time Series Forecasting with improvements for handling time series data.
    """
    # Encoder
    encoder_inputs = Input(shape=(input_seq_len, input_dim), name="encoder_inputs")

    # Temporal Convolutional Layers for better feature extraction in time series data
    encoder_conv = Conv1D(filters=64, kernel_size=3, activation='relu', padding='same', name="encoder_conv")(encoder_inputs)
    encoder_conv = Dropout(0.3, name="encoder_conv_dropout")(encoder_conv)

    # Bidirectional LSTM for Encoder to capture patterns from both directions
    encoder_lstm = Bidirectional(LSTM(latent_dim, return_sequences=True, return_state=True, name="encoder_lstm"))
    encoder_outputs, forward_h, forward_c, backward_h, backward_c = encoder_lstm(encoder_conv)  # Adjusted unpacking

    # Combine forward and backward states to form initial state for decoder
    state_h = Concatenate()([forward_h, backward_h])
    state_c = Concatenate()([forward_c, backward_c])

    # Multi-Head Attention for Encoder
    multi_head_attention = MultiHeadAttention(num_heads=4, key_dim=latent_dim, name="multi_head_attention")
    encoder_attention = multi_head_attention(encoder_outputs, encoder_outputs)  # Query and value are the same
    encoder_attention = LayerNormalization(name="encoder_attention_norm")(encoder_attention)

    # Decoder
    decoder_inputs = Input(shape=(output_seq_len, input_dim), name="decoder_inputs")

    # Convolutional Layer in Decoder
    decoder_conv = Conv1D(filters=64, kernel_size=3, activation='relu', padding='same', name="decoder_conv")(decoder_inputs)
    decoder_conv = Dropout(0.3, name="decoder_conv_dropout")(decoder_conv)

    # Decoder LSTM, using encoder states for initialization
    decoder_lstm = LSTM(latent_dim * 2, return_sequences=True, return_state=True, name="decoder_lstm")
    decoder_outputs, _, _ = decoder_lstm(decoder_conv, initial_state=[state_h, state_c])

    # Ensure that the attention mechanism has compatible shapes (query and value)
    attention_context = multi_head_attention(decoder_outputs, encoder_attention)  # Using encoder attention in decoder
    attention_context = LayerNormalization(name="decoder_attention_norm")(attention_context)
    attention_context = Lambda(lambda x: tf.reduce_mean(x, axis=1), name="summarize_attention")(attention_context)

    # Ensure Attention Context and Decoder Outputs have compatible dimensions
    attention_context_repeated = RepeatVector(output_seq_len)(attention_context)  # Repeat to match output_seq_len
    attention_context_repeated = tf.keras.layers.Reshape((output_seq_len, latent_dim * 2))(attention_context_repeated)

    # Merge Attention Context with Decoder Outputs
    merged_context = Concatenate(axis=-1)([decoder_outputs, attention_context_repeated])

    # Dropout and Output Layers
    dropout = Dropout(0.4, name="decoder_dropout")(merged_context)
    output_mean = Dense(output_dim, activation="linear", kernel_regularizer=tf.keras.regularizers.l2(1e-4),
                        name="mean_output")(dropout)
    output_std = Dense(output_dim, activation="softplus", kernel_regularizer=tf.keras.regularizers.l2(1e-4),
                       name="std_output")(dropout)

    # Combine Outputs
    outputs = Concatenate(name="probabilistic_outputs")([output_mean, output_std])

    # Define the Model
    model = Model(inputs=[encoder_inputs, decoder_inputs], outputs=outputs, name="enhanced_probabilistic_seq2seq_model")

    # Custom Loss Function (Negative Log-Likelihood)
    def nll_loss(y_true, y_pred):
        mean = y_pred[..., :output_dim]
        std = y_pred[..., output_dim:]
        dist = tf.compat.v1.distributions.Normal(loc=mean, scale=std)
        return -tf.reduce_mean(dist.log_prob(y_true))

    # Probabilistic Evaluation Metric: CRPS
    def crps_metric(y_true, y_pred):
        mean = y_pred[..., :output_dim]
        std = y_pred[..., output_dim:]
        return tf.reduce_mean((y_true - mean) ** 2 / (2 * std ** 2) + tf.math.log(std))

    # Adjusted R² Metric
    def adjusted_r2_score(y_true, y_pred):
        mean = y_pred[..., :output_dim]
        ss_res = tf.reduce_sum(tf.square(y_true - mean), axis=-1)
        ss_tot = tf.reduce_sum(tf.square(y_true - tf.reduce_mean(y_true, axis=-1, keepdims=True)), axis=-1)
        r2 = 1 - (ss_res / (ss_tot + tf.keras.backend.epsilon()))

        # Number of samples (batch size)
        n = tf.cast(tf.shape(y_true)[0], tf.float32)

        # Number of predictors (features)
        p = tf.cast(output_dim, tf.float32)

        # Adjusted R²
        adjusted_r2 = 1 - ((1 - r2) * (n - 1)) / (n - p - 1 + tf.keras.backend.epsilon())
        return adjusted_r2

    # Optimizer
    optimizer = Adam(learning_rate=0.01)

    # Compile the Model
    model.compile(optimizer=optimizer, loss=nll_loss, metrics=[crps_metric, adjusted_r2_score])

    return model

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# Hyperparameters
input_seq_len = 5  # Input sequence length
output_seq_len = 2  # Output sequence length
latent_dim = 64  # Number of LSTM units
input_dim = len(input_features)  # Number of input features
output_dim = len(output_features)  # Number of output features

# Create the model
model = create_advanced_probabilistic_seq2seq(input_seq_len, output_seq_len, input_dim, output_dim, latent_dim)

# Callbacks
lr_scheduler = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=5, verbose=1)
early_stopping = EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True, verbose=1)

# Train the model
print("Training the model...")
history = model.fit(
    [train_enc_inputs, train_dec_inputs],
    train_targets,
    validation_data=([val_enc_inputs, val_dec_inputs], val_targets),
    batch_size=32,
    epochs=100,
    callbacks=[lr_scheduler, early_stopping],
    verbose=1
)

# Save the Model
model.save_weights("prob_attention_lstm.weights.h5")
print("Model saved successfully.")
# Out:
# Training the model...
# Epoch 1/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 72ms/step - adjusted_r2_score: -0.2626 - crps_metric: 7789423.5000 - loss: 7789625.5000 - val_adjusted_r2_score: -0.2605 - val_crps_metric: 14916.7324 - val_loss: 14917.3730 - learning_rate: 0.0100
# Epoch 2/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - adjusted_r2_score: -0.2586 - crps_metric: 13935.2100 - loss: 13936.4287 - val_adjusted_r2_score: -0.2565 - val_crps_metric: 9729.5205 - val_loss: 9730.2637 - learning_rate: 0.0100
# Epoch 3/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - adjusted_r2_score: -0.2538 - crps_metric: 9878.3779 - loss: 9879.2852 - val_adjusted_r2_score: -0.2532 - val_crps_metric: 7622.1250 - val_loss: 7622.9268 - learning_rate: 0.0100
# Epoch 4/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 10s 61ms/step - adjusted_r2_score: -0.2512 - crps_metric: 7941.8506 - loss: 7942.8301 - val_adjusted_r2_score: -0.2500 - val_crps_metric: 6302.7095 - val_loss: 6303.5117 - learning_rate: 0.0100
# Epoch 5/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 9s 50ms/step - adjusted_r2_score: -0.2489 - crps_metric: 6672.7388 - loss: 6673.7666 - val_adjusted_r2_score: -0.2470 - val_crps_metric: 5413.0303 - val_loss: 5413.8574 - learning_rate: 0.0100
# Epoch 6/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - adjusted_r2_score: -0.2450 - crps_metric: 5698.6113 - loss: 5699.4141 - val_adjusted_r2_score: -0.2436 - val_crps_metric: 4667.3955 - val_loss: 4668.2529 - learning_rate: 0.0100
# Epoch 7/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 49ms/step - adjusted_r2_score: -0.2424 - crps_metric: 5102.2896 - loss: 5103.3350 - val_adjusted_r2_score: -0.2407 - val_crps_metric: 4174.0908 - val_loss: 4174.9814 - learning_rate: 0.0100
# Epoch 8/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - adjusted_r2_score: -0.2394 - crps_metric: 4592.7285 - loss: 4593.7622 - val_adjusted_r2_score: -0.2378 - val_crps_metric: 3786.9436 - val_loss: 3787.8479 - learning_rate: 0.0100
# Epoch 9/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - adjusted_r2_score: -0.2361 - crps_metric: 4176.2974 - loss: 4177.1133 - val_adjusted_r2_score: -0.2350 - val_crps_metric: 3457.4119 - val_loss: 3458.3145 - learning_rate: 0.0100
# Epoch 10/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - adjusted_r2_score: -0.2341 - crps_metric: 3893.1860 - loss: 3894.1726 - val_adjusted_r2_score: -0.2321 - val_crps_metric: 3191.4297 - val_loss: 3192.3674 - learning_rate: 0.0100
# Epoch 11/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - adjusted_r2_score: -0.2306 - crps_metric: 3616.7480 - loss: 3617.7727 - val_adjusted_r2_score: -0.2292 - val_crps_metric: 2941.7908 - val_loss: 2942.7195 - learning_rate: 0.0100
# Epoch 12/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - adjusted_r2_score: -0.2268 - crps_metric: 3386.5898 - loss: 3387.6277 - val_adjusted_r2_score: -0.2263 - val_crps_metric: 2729.0803 - val_loss: 2730.0388 - learning_rate: 0.0100
# Epoch 13/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - adjusted_r2_score: -0.2249 - crps_metric: 3145.3274 - loss: 3146.3293 - val_adjusted_r2_score: -0.2234 - val_crps_metric: 2563.4302 - val_loss: 2564.3916 - learning_rate: 0.0100
# Epoch 14/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - adjusted_r2_score: -0.2212 - crps_metric: 2975.7893 - loss: 2976.7878 - val_adjusted_r2_score: -0.2200 - val_crps_metric: 2387.3955 - val_loss: 2388.3906 - learning_rate: 0.0100
# Epoch 15/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - adjusted_r2_score: -0.2185 - crps_metric: 2829.4744 - loss: 2830.5474 - val_adjusted_r2_score: -0.2165 - val_crps_metric: 2230.2861 - val_loss: 2231.3013 - learning_rate: 0.0100
# Epoch 16/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 58ms/step - adjusted_r2_score: -0.2143 - crps_metric: 2561.2915 - loss: 2562.3428 - val_adjusted_r2_score: -0.2133 - val_crps_metric: 2103.8650 - val_loss: 2104.8970 - learning_rate: 0.0100
# Epoch 17/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - adjusted_r2_score: -0.2111 - crps_metric: 2481.4958 - loss: 2482.5237 - val_adjusted_r2_score: -0.2103 - val_crps_metric: 1991.9802 - val_loss: 1993.0148 - learning_rate: 0.0100
# Epoch 18/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - adjusted_r2_score: -0.2087 - crps_metric: 2353.6064 - loss: 2354.7095 - val_adjusted_r2_score: -0.2066 - val_crps_metric: 1882.6437 - val_loss: 1883.7123 - learning_rate: 0.0100
# Epoch 19/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - adjusted_r2_score: -0.2048 - crps_metric: 2215.2622 - loss: 2216.2834 - val_adjusted_r2_score: -0.2031 - val_crps_metric: 1787.2694 - val_loss: 1788.3531 - learning_rate: 0.0100
# Epoch 20/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 10s 49ms/step - adjusted_r2_score: -0.2020 - crps_metric: 2108.3550 - loss: 2109.5088 - val_adjusted_r2_score: -0.1999 - val_crps_metric: 1699.7145 - val_loss: 1700.8170 - learning_rate: 0.0100
# Epoch 21/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - adjusted_r2_score: -0.1967 - crps_metric: 1963.9475 - loss: 1965.0994 - val_adjusted_r2_score: -0.1962 - val_crps_metric: 1617.2000 - val_loss: 1618.3235 - learning_rate: 0.0100
# Epoch 22/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 49ms/step - adjusted_r2_score: -0.1942 - crps_metric: 1941.1847 - loss: 1942.3708 - val_adjusted_r2_score: -0.1924 - val_crps_metric: 1542.9159 - val_loss: 1544.0557 - learning_rate: 0.0100
# Epoch 23/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - adjusted_r2_score: -0.1910 - crps_metric: 1847.6329 - loss: 1848.7883 - val_adjusted_r2_score: -0.1890 - val_crps_metric: 1479.6118 - val_loss: 1480.7726 - learning_rate: 0.0100
# Epoch 24/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - adjusted_r2_score: -0.1877 - crps_metric: 1757.2089 - loss: 1758.4357 - val_adjusted_r2_score: -0.1844 - val_crps_metric: 1410.6251 - val_loss: 1411.8113 - learning_rate: 0.0100
# Epoch 25/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - adjusted_r2_score: -0.1825 - crps_metric: 1715.6521 - loss: 1716.8320 - val_adjusted_r2_score: -0.1810 - val_crps_metric: 1349.4351 - val_loss: 1350.6385 - learning_rate: 0.0100
# Epoch 26/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - adjusted_r2_score: -0.1792 - crps_metric: 1637.3263 - loss: 1638.5238 - val_adjusted_r2_score: -0.1772 - val_crps_metric: 1292.7402 - val_loss: 1293.9659 - learning_rate: 0.0100
# Epoch 27/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - adjusted_r2_score: -0.1759 - crps_metric: 1584.0050 - loss: 1585.2882 - val_adjusted_r2_score: -0.1730 - val_crps_metric: 1239.5465 - val_loss: 1240.7944 - learning_rate: 0.0100
# Epoch 28/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - adjusted_r2_score: -0.1708 - crps_metric: 1492.5696 - loss: 1493.8511 - val_adjusted_r2_score: -0.1687 - val_crps_metric: 1189.7852 - val_loss: 1191.0551 - learning_rate: 0.0100
# Epoch 29/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - adjusted_r2_score: -0.1669 - crps_metric: 1407.8850 - loss: 1409.2136 - val_adjusted_r2_score: -0.1649 - val_crps_metric: 1145.5287 - val_loss: 1146.8228 - learning_rate: 0.0100
# Epoch 30/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - adjusted_r2_score: -0.1622 - crps_metric: 1413.3705 - loss: 1414.7148 - val_adjusted_r2_score: -0.1599 - val_crps_metric: 1097.4193 - val_loss: 1098.7378 - learning_rate: 0.0100
# Epoch 31/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 49ms/step - adjusted_r2_score: -0.1578 - crps_metric: 1316.1805 - loss: 1317.5192 - val_adjusted_r2_score: -0.1555 - val_crps_metric: 1056.3065 - val_loss: 1057.6501 - learning_rate: 0.0100
# Epoch 32/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - adjusted_r2_score: -0.1526 - crps_metric: 1276.4854 - loss: 1277.8328 - val_adjusted_r2_score: -0.1496 - val_crps_metric: 1013.3127 - val_loss: 1014.6847 - learning_rate: 0.0100
# Epoch 33/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - adjusted_r2_score: -0.1473 - crps_metric: 1250.1475 - loss: 1251.5073 - val_adjusted_r2_score: -0.1431 - val_crps_metric: 970.0961 - val_loss: 971.4972 - learning_rate: 0.0100
# Epoch 34/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - adjusted_r2_score: -0.1409 - crps_metric: 1163.9360 - loss: 1165.3264 - val_adjusted_r2_score: -0.1364 - val_crps_metric: 930.1782 - val_loss: 931.6047 - learning_rate: 0.0100
# Epoch 35/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 9s 47ms/step - adjusted_r2_score: -0.1357 - crps_metric: 1160.1609 - loss: 1161.6151 - val_adjusted_r2_score: -0.1295 - val_crps_metric: 890.8312 - val_loss: 892.2886 - learning_rate: 0.0100
# Epoch 36/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - adjusted_r2_score: -0.1282 - crps_metric: 1088.1112 - loss: 1089.5667 - val_adjusted_r2_score: -0.1221 - val_crps_metric: 852.4133 - val_loss: 853.9001 - learning_rate: 0.0100
# Epoch 37/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 49ms/step - adjusted_r2_score: -0.1201 - crps_metric: 1046.1193 - loss: 1047.6173 - val_adjusted_r2_score: -0.1139 - val_crps_metric: 815.7336 - val_loss: 817.2515 - learning_rate: 0.0100
# Epoch 38/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - adjusted_r2_score: -0.1129 - crps_metric: 998.4626 - loss: 1000.0128 - val_adjusted_r2_score: -0.1049 - val_crps_metric: 779.6188 - val_loss: 781.1690 - learning_rate: 0.0100
# Epoch 39/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - adjusted_r2_score: -0.1024 - crps_metric: 968.9111 - loss: 970.4894 - val_adjusted_r2_score: -0.0944 - val_crps_metric: 743.6056 - val_loss: 745.1893 - learning_rate: 0.0100
# Epoch 40/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - adjusted_r2_score: -0.0922 - crps_metric: 920.2878 - loss: 921.8996 - val_adjusted_r2_score: -0.0838 - val_crps_metric: 708.4038 - val_loss: 710.0214 - learning_rate: 0.0100
# Epoch 41/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - adjusted_r2_score: -0.0818 - crps_metric: 870.1655 - loss: 871.7982 - val_adjusted_r2_score: -0.0715 - val_crps_metric: 673.6898 - val_loss: 675.3429 - learning_rate: 0.0100
# Epoch 42/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - adjusted_r2_score: -0.0685 - crps_metric: 826.2126 - loss: 827.8838 - val_adjusted_r2_score: -0.0570 - val_crps_metric: 638.7666 - val_loss: 640.4544 - learning_rate: 0.0100
# Epoch 43/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - adjusted_r2_score: -0.0542 - crps_metric: 805.9650 - loss: 807.6716 - val_adjusted_r2_score: -0.0407 - val_crps_metric: 603.4180 - val_loss: 605.1428 - learning_rate: 0.0100
# Epoch 44/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - adjusted_r2_score: -0.0418 - crps_metric: 758.0327 - loss: 759.7825 - val_adjusted_r2_score: -0.0255 - val_crps_metric: 571.2945 - val_loss: 573.0546 - learning_rate: 0.0100
# Epoch 45/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - adjusted_r2_score: -0.0224 - crps_metric: 729.2202 - loss: 730.9700 - val_adjusted_r2_score: -0.0082 - val_crps_metric: 538.6136 - val_loss: 540.4133 - learning_rate: 0.0100
# Epoch 46/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 9s 50ms/step - adjusted_r2_score: -0.0035 - crps_metric: 695.2496 - loss: 697.0680 - val_adjusted_r2_score: 0.0123 - val_crps_metric: 505.4113 - val_loss: 507.2513 - learning_rate: 0.0100
# Epoch 47/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - adjusted_r2_score: 0.0192 - crps_metric: 648.5416 - loss: 650.3896 - val_adjusted_r2_score: 0.0350 - val_crps_metric: 472.3530 - val_loss: 474.2306 - learning_rate: 0.0100
# Epoch 48/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - adjusted_r2_score: 0.0352 - crps_metric: 632.6769 - loss: 634.5593 - val_adjusted_r2_score: 0.0565 - val_crps_metric: 442.7191 - val_loss: 444.6370 - learning_rate: 0.0100
# Epoch 49/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - adjusted_r2_score: 0.0544 - crps_metric: 602.5928 - loss: 604.4998 - val_adjusted_r2_score: 0.0829 - val_crps_metric: 414.2957 - val_loss: 416.2525 - learning_rate: 0.0100
# Epoch 50/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - adjusted_r2_score: 0.0760 - crps_metric: 579.1798 - loss: 581.1516 - val_adjusted_r2_score: 0.0953 - val_crps_metric: 392.4418 - val_loss: 394.4365 - learning_rate: 0.0100
# Epoch 51/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - adjusted_r2_score: 0.0955 - crps_metric: 553.1848 - loss: 555.1653 - val_adjusted_r2_score: 0.1238 - val_crps_metric: 363.3438 - val_loss: 365.3802 - learning_rate: 0.0100
# Epoch 52/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 9s 50ms/step - adjusted_r2_score: 0.1182 - crps_metric: 521.3488 - loss: 523.3928 - val_adjusted_r2_score: 0.1517 - val_crps_metric: 337.1728 - val_loss: 339.2524 - learning_rate: 0.0100
# Epoch 53/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - adjusted_r2_score: 0.1336 - crps_metric: 510.7279 - loss: 512.8208 - val_adjusted_r2_score: 0.1690 - val_crps_metric: 318.5829 - val_loss: 320.7034 - learning_rate: 0.0100
# Epoch 54/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - adjusted_r2_score: 0.1672 - crps_metric: 469.6221 - loss: 471.7613 - val_adjusted_r2_score: 0.1992 - val_crps_metric: 294.4588 - val_loss: 296.6229 - learning_rate: 0.0100
# Epoch 55/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - adjusted_r2_score: 0.1937 - crps_metric: 433.7548 - loss: 435.9245 - val_adjusted_r2_score: 0.2275 - val_crps_metric: 272.8458 - val_loss: 275.0546 - learning_rate: 0.0100
# Epoch 56/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - adjusted_r2_score: 0.2038 - crps_metric: 433.8963 - loss: 436.1120 - val_adjusted_r2_score: 0.2553 - val_crps_metric: 252.6184 - val_loss: 254.8709 - learning_rate: 0.0100
# Epoch 57/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - adjusted_r2_score: 0.2305 - crps_metric: 422.3686 - loss: 424.6290 - val_adjusted_r2_score: 0.2719 - val_crps_metric: 239.2173 - val_loss: 241.5147 - learning_rate: 0.0100
# Epoch 58/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - adjusted_r2_score: 0.2391 - crps_metric: 411.6472 - loss: 413.9522 - val_adjusted_r2_score: 0.2975 - val_crps_metric: 222.9227 - val_loss: 225.2621 - learning_rate: 0.0100
# Epoch 59/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - adjusted_r2_score: 0.2573 - crps_metric: 391.1759 - loss: 393.5200 - val_adjusted_r2_score: 0.3175 - val_crps_metric: 209.6203 - val_loss: 212.0063 - learning_rate: 0.0100
# Epoch 60/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - adjusted_r2_score: 0.2831 - crps_metric: 388.7566 - loss: 391.1730 - val_adjusted_r2_score: 0.3378 - val_crps_metric: 196.9782 - val_loss: 199.4140 - learning_rate: 0.0100
# Epoch 61/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - adjusted_r2_score: 0.2944 - crps_metric: 367.1997 - loss: 369.6493 - val_adjusted_r2_score: 0.3616 - val_crps_metric: 183.7425 - val_loss: 186.2271 - learning_rate: 0.0100
# Epoch 62/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - adjusted_r2_score: 0.3231 - crps_metric: 336.9478 - loss: 339.4352 - val_adjusted_r2_score: 0.3770 - val_crps_metric: 174.5117 - val_loss: 177.0431 - learning_rate: 0.0100
# Epoch 63/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - adjusted_r2_score: 0.3272 - crps_metric: 335.4661 - loss: 338.0123 - val_adjusted_r2_score: 0.3961 - val_crps_metric: 164.6518 - val_loss: 167.2368 - learning_rate: 0.0100
# Epoch 64/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - adjusted_r2_score: 0.3608 - crps_metric: 320.5036 - loss: 323.0903 - val_adjusted_r2_score: 0.4224 - val_crps_metric: 152.2826 - val_loss: 154.9190 - learning_rate: 0.0100
# Epoch 65/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - adjusted_r2_score: 0.3610 - crps_metric: 317.1552 - loss: 319.8117 - val_adjusted_r2_score: 0.4364 - val_crps_metric: 145.3319 - val_loss: 148.0161 - learning_rate: 0.0100
# Epoch 66/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 51ms/step - adjusted_r2_score: 0.3735 - crps_metric: 318.5659 - loss: 321.2706 - val_adjusted_r2_score: 0.4588 - val_crps_metric: 135.7580 - val_loss: 138.5005 - learning_rate: 0.0100
# Epoch 67/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - adjusted_r2_score: 0.3977 - crps_metric: 281.3829 - loss: 284.1434 - val_adjusted_r2_score: 0.4751 - val_crps_metric: 127.9782 - val_loss: 130.7735 - learning_rate: 0.0100
# Epoch 68/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - adjusted_r2_score: 0.4048 - crps_metric: 286.0706 - loss: 288.8787 - val_adjusted_r2_score: 0.4738 - val_crps_metric: 126.8206 - val_loss: 129.6676 - learning_rate: 0.0100
# Epoch 69/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - adjusted_r2_score: 0.4214 - crps_metric: 272.9637 - loss: 275.8166 - val_adjusted_r2_score: 0.4994 - val_crps_metric: 116.8016 - val_loss: 119.7092 - learning_rate: 0.0100
# Epoch 70/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - adjusted_r2_score: 0.4316 - crps_metric: 257.0500 - loss: 259.9525 - val_adjusted_r2_score: 0.5132 - val_crps_metric: 111.1161 - val_loss: 114.0770 - learning_rate: 0.0100
# Epoch 71/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - adjusted_r2_score: 0.4396 - crps_metric: 261.2616 - loss: 264.2479 - val_adjusted_r2_score: 0.5415 - val_crps_metric: 101.7005 - val_loss: 104.7228 - learning_rate: 0.0100
# Epoch 72/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - adjusted_r2_score: 0.4492 - crps_metric: 251.8525 - loss: 254.8991 - val_adjusted_r2_score: 0.5530 - val_crps_metric: 97.0313 - val_loss: 100.1119 - learning_rate: 0.0100
# Epoch 73/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 49ms/step - adjusted_r2_score: 0.4666 - crps_metric: 242.1247 - loss: 245.2202 - val_adjusted_r2_score: 0.5714 - val_crps_metric: 90.8816 - val_loss: 94.0232 - learning_rate: 0.0100
# Epoch 74/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - adjusted_r2_score: 0.4774 - crps_metric: 238.5833 - loss: 241.7513 - val_adjusted_r2_score: 0.5757 - val_crps_metric: 88.6496 - val_loss: 91.8527 - learning_rate: 0.0100
# Epoch 75/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 51ms/step - adjusted_r2_score: 0.4819 - crps_metric: 228.4675 - loss: 231.6897 - val_adjusted_r2_score: 0.5874 - val_crps_metric: 84.6170 - val_loss: 87.8826 - learning_rate: 0.0100
# Epoch 76/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - adjusted_r2_score: 0.4855 - crps_metric: 218.0743 - loss: 221.3676 - val_adjusted_r2_score: 0.5964 - val_crps_metric: 81.3256 - val_loss: 84.6592 - learning_rate: 0.0100
# Epoch 77/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - adjusted_r2_score: 0.5060 - crps_metric: 206.4097 - loss: 209.7675 - val_adjusted_r2_score: 0.6137 - val_crps_metric: 76.1203 - val_loss: 79.5248 - learning_rate: 0.0100
# Epoch 78/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - adjusted_r2_score: 0.5051 - crps_metric: 208.5801 - loss: 212.0074 - val_adjusted_r2_score: 0.6315 - val_crps_metric: 71.5229 - val_loss: 75.0018 - learning_rate: 0.0100
# Epoch 79/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 10s 50ms/step - adjusted_r2_score: 0.5235 - crps_metric: 193.1234 - loss: 196.6152 - val_adjusted_r2_score: 0.6329 - val_crps_metric: 69.5054 - val_loss: 73.0575 - learning_rate: 0.0100
# Epoch 80/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - adjusted_r2_score: 0.5240 - crps_metric: 190.9537 - loss: 194.5317 - val_adjusted_r2_score: 0.6500 - val_crps_metric: 64.8017 - val_loss: 68.4283 - learning_rate: 0.0100
# Epoch 81/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - adjusted_r2_score: 0.5351 - crps_metric: 180.0586 - loss: 183.7125 - val_adjusted_r2_score: 0.6552 - val_crps_metric: 62.6748 - val_loss: 66.3775 - learning_rate: 0.0100
# Epoch 82/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 12s 75ms/step - adjusted_r2_score: 0.5440 - crps_metric: 174.1810 - loss: 177.9132 - val_adjusted_r2_score: 0.6661 - val_crps_metric: 59.5006 - val_loss: 63.2778 - learning_rate: 0.0100
# Epoch 83/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 49ms/step - adjusted_r2_score: 0.5590 - crps_metric: 161.6070 - loss: 165.4131 - val_adjusted_r2_score: 0.6745 - val_crps_metric: 57.1987 - val_loss: 61.0501 - learning_rate: 0.0100
# Epoch 84/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - adjusted_r2_score: 0.5465 - crps_metric: 161.3402 - loss: 165.2044 - val_adjusted_r2_score: 0.6864 - val_crps_metric: 54.0400 - val_loss: 57.9677 - learning_rate: 0.0100
# Epoch 85/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 51ms/step - adjusted_r2_score: 0.5565 - crps_metric: 153.8667 - loss: 157.8132 - val_adjusted_r2_score: 0.6975 - val_crps_metric: 51.1273 - val_loss: 55.1333 - learning_rate: 0.0100
# Epoch 86/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - adjusted_r2_score: 0.5419 - crps_metric: 160.9035 - loss: 164.9426 - val_adjusted_r2_score: 0.6962 - val_crps_metric: 50.6826 - val_loss: 54.7696 - learning_rate: 0.0100
# Epoch 87/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 51ms/step - adjusted_r2_score: 0.5588 - crps_metric: 147.6978 - loss: 151.8087 - val_adjusted_r2_score: 0.7045 - val_crps_metric: 48.4296 - val_loss: 52.5959 - learning_rate: 0.0100
# Epoch 88/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - adjusted_r2_score: 0.5688 - crps_metric: 148.7080 - loss: 152.9029 - val_adjusted_r2_score: 0.7122 - val_crps_metric: 46.6385 - val_loss: 50.8864 - learning_rate: 0.0100
# Epoch 89/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - adjusted_r2_score: 0.5874 - crps_metric: 126.8518 - loss: 131.1250 - val_adjusted_r2_score: 0.7100 - val_crps_metric: 46.7258 - val_loss: 51.0503 - learning_rate: 0.0100
# Epoch 90/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - adjusted_r2_score: 0.5828 - crps_metric: 129.5882 - loss: 133.9369 - val_adjusted_r2_score: 0.7286 - val_crps_metric: 42.8961 - val_loss: 47.3028 - learning_rate: 0.0100
# Epoch 91/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 9s 53ms/step - adjusted_r2_score: 0.5898 - crps_metric: 127.6484 - loss: 132.0838 - val_adjusted_r2_score: 0.7367 - val_crps_metric: 41.0475 - val_loss: 45.5365 - learning_rate: 0.0100
# Epoch 92/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 11s 57ms/step - adjusted_r2_score: 0.6025 - crps_metric: 122.0734 - loss: 126.5790 - val_adjusted_r2_score: 0.7418 - val_crps_metric: 39.6289 - val_loss: 44.1990 - learning_rate: 0.0100
# Epoch 93/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - adjusted_r2_score: 0.6127 - crps_metric: 110.2637 - loss: 114.8597 - val_adjusted_r2_score: 0.7537 - val_crps_metric: 37.2392 - val_loss: 41.8875 - learning_rate: 0.0100
# Epoch 94/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - adjusted_r2_score: 0.6118 - crps_metric: 111.6556 - loss: 116.3006 - val_adjusted_r2_score: 0.7571 - val_crps_metric: 36.2277 - val_loss: 40.9551 - learning_rate: 0.0100
# Epoch 95/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - adjusted_r2_score: 0.6239 - crps_metric: 104.0524 - loss: 108.8064 - val_adjusted_r2_score: 0.7621 - val_crps_metric: 35.0151 - val_loss: 39.8251 - learning_rate: 0.0100
# Epoch 96/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - adjusted_r2_score: 0.6272 - crps_metric: 105.7608 - loss: 110.5967 - val_adjusted_r2_score: 0.7682 - val_crps_metric: 33.5106 - val_loss: 38.4023 - learning_rate: 0.0100
# Epoch 97/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - adjusted_r2_score: 0.6300 - crps_metric: 95.5271 - loss: 100.4414 - val_adjusted_r2_score: 0.7772 - val_crps_metric: 31.6689 - val_loss: 36.6383 - learning_rate: 0.0100
# Epoch 98/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - adjusted_r2_score: 0.6559 - crps_metric: 83.8524 - loss: 88.8463 - val_adjusted_r2_score: 0.7915 - val_crps_metric: 29.0990 - val_loss: 34.1433 - learning_rate: 0.0100
# Epoch 99/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - adjusted_r2_score: 0.6667 - crps_metric: 80.0533 - loss: 85.1161 - val_adjusted_r2_score: 0.8033 - val_crps_metric: 27.0263 - val_loss: 32.1423 - learning_rate: 0.0100
# Epoch 100/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - adjusted_r2_score: 0.6821 - crps_metric: 77.0466 - loss: 82.1845 - val_adjusted_r2_score: 0.8155 - val_crps_metric: 24.8353 - val_loss: 30.0179 - learning_rate: 0.0100
# Restoring model weights from the end of the best epoch: 100.
# Model saved successfully.
