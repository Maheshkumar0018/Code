# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from scipy.interpolate import interp1d
from tqdm import tqdm
warnings.filterwarnings('ignore', category=RuntimeWarning)
warnings.filterwarnings('ignore')

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
from tqdm import tqdm

def sliding_window_segmentation(data, window_size, step_size, mmsi):
    segments = []
    for start in range(0, len(data) - window_size + 1, step_size):
        window = data.iloc[start:start + window_size].copy()
        window['MMSI'] = mmsi
        segments.append(window)
    return segments

def lat_lon_range(df_file):
    min_lat, max_lat = df_file['LAT'].min(), df_file['LAT'].max()
    min_lon, max_lon = df_file['LON'].min(), df_file['LON'].max()
    min_lat, max_lat, min_lon, max_lon = (
        int(np.floor(min_lat)),
        int(np.ceil(max_lat)),
        int(np.floor(min_lon)),
        int(np.ceil(max_lon)),
    )
    return min_lat, max_lat, min_lon, max_lon

def prepare_ais_data_without_interpolation(
    data, bounding_box, window_size, step_size
):
    min_lat, max_lat, min_lon, max_lon = bounding_box

    filtered_data = data[
        (data['LAT'] >= min_lat) & (data['LAT'] <= max_lat) &
        (data['LON'] >= min_lon) & (data['LON'] <= max_lon)
    ]

    grouped = filtered_data.groupby('MMSI')
    segments = []
    segment_id = 0

    for mmsi, group in tqdm(grouped, desc="Processing MMSI", unit="MMSI"):
        group = group.sort_values(by='BaseDateTime')
        group['BaseDateTime'] = pd.to_datetime(group['BaseDateTime'])

        # Directly use the existing data without interpolation
        resampled_traj = group[['BaseDateTime', 'LAT', 'LON', 'SOG', 'COG']].copy()

        trajectory_segments = sliding_window_segmentation(resampled_traj, window_size, step_size, mmsi)

        for segment in trajectory_segments:
            segment['SegmentID'] = segment_id
            segments.append(segment)
            segment_id += 1

    combined_df = pd.concat(segments, ignore_index=True)
    return combined_df

# Example usage
if __name__ == "__main__":
    df = pd.read_csv("/content/modified_ais_data.csv")[:100000]

    # Define bounding box from the dataset
    min_lat, max_lat, min_lon, max_lon = lat_lon_range(df)
    bounding_box = (min_lat, max_lat, min_lon, max_lon)

    window_size = 10
    step_size = 5

    segmented_trajectories_df = prepare_ais_data_without_interpolation(
        df, bounding_box, window_size, step_size
    )

    segmented_trajectories_df.to_csv("segmented_trajectories.csv", index=False)
# Out:
# Processing MMSI: 100%|██████████| 3093/3093 [00:16<00:00, 192.70MMSI/s]

# %% [markdown]
# ### calculate duration

# %%
def calculate_durations(group):
    # Ensure BaseDateTime is a datetime type
    group['BaseDateTime'] = pd.to_datetime(group['BaseDateTime'])
    # Calculate the duration between consecutive points in seconds
    group['duration_seconds'] = group['BaseDateTime'].diff().dt.total_seconds()
    return group

# %%
segmented_trajectories_df = segmented_trajectories_df.sort_values(by=['BaseDateTime'])
segmented_trajectories_df = segmented_trajectories_df.groupby("MMSI", group_keys=False).apply(calculate_durations)
segmented_trajectories_df = segmented_trajectories_df.reset_index(drop=True)
segmented_trajectories_df.head()
# Out:
#   BaseDateTime       LAT        LON  SOG    COG       MMSI  SegmentID  \
# 0   2022-03-31  32.65303 -117.12239  1.7  166.4  366764730       4891
# 1   2022-03-31  34.36573 -121.77418  7.9  278.0  356909000       4471
# 2   2022-03-31  48.47441 -125.41904  1.0  115.0  357175000       4478
# 3   2022-03-31  29.74757  -95.11144  0.0  238.0  367141680       6735
# 4   2022-03-31  24.08663  -82.27491  9.4   57.0  319874000       3544
#
#    duration_seconds
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
segmented_trajectories_df.isna().sum()
# Out:
# BaseDateTime           0
# LAT                    0
# LON                    0
# SOG                    0
# COG                    0
# MMSI                   0
# SegmentID              0
# duration_seconds    2750
# dtype: int64

# %%
segmented_trajectories_df.shape
# Out:
# (158270, 8)

# %%
segmented_trajectories_df.fillna(0,inplace=True)

# %%
segmented_trajectories_df.isna().sum()
# Out:
# BaseDateTime        0
# LAT                 0
# LON                 0
# SOG                 0
# COG                 0
# MMSI                0
# SegmentID           0
# duration_seconds    0
# dtype: int64

# %% [markdown]
# ### calculate x,y,z

# %%
import math

def lat_lon_to_cartesian(lat, lon, R=6371):
    lat_rad = math.radians(lat)
    lon_rad = math.radians(lon)
    x = R * math.cos(lat_rad) * math.cos(lon_rad)
    y = R * math.cos(lat_rad) * math.sin(lon_rad)
    z = R * math.sin(lat_rad)
    return x, y, z

def cartesian_to_lat_lon(x, y, z, R=6371):
    lon = math.degrees(math.atan2(y, x))
    lat = math.degrees(math.asin(z / R))
    return lat, lon

# %%
segmented_trajectories_df[['x', 'y', 'z']] = segmented_trajectories_df.apply(lambda row: pd.Series(lat_lon_to_cartesian(row['LAT'], row['LON'])), axis=1)
segmented_trajectories_df.head()
# Out:
#   BaseDateTime       LAT        LON  SOG    COG       MMSI  SegmentID  \
# 0   2022-03-31  32.65303 -117.12239  1.7  166.4  366764730       4891
# 1   2022-03-31  34.36573 -121.77418  7.9  278.0  356909000       4471
# 2   2022-03-31  48.47441 -125.41904  1.0  115.0  357175000       4478
# 3   2022-03-31  29.74757  -95.11144  0.0  238.0  367141680       6735
# 4   2022-03-31  24.08663  -82.27491  9.4   57.0  319874000       3544
#
#    duration_seconds            x            y            z
# 0               0.0 -2445.447444 -4774.221861  3437.474862
# 1               0.0 -2769.219752 -4470.791605  3596.259916
# 2               0.0 -2447.844023 -3442.028194  4769.710950
# 3               0.0  -492.812521 -5509.431869  3161.160752
# 4               0.0   781.824216 -5763.487453  2600.116203

# %% [markdown]
# ### calculate distance

# %%
import numpy as np
def haversine(lat1, lon1, lat2, lon2, R=6371):
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat / 2) ** 2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2) ** 2
    c = 2 * np.arcsin(np.sqrt(a))
    return R * c

def calculate_distances(group):
    group = group.sort_values(by="BaseDateTime")
    group["next_lat"] = group["LAT"].shift(-1)
    group["next_long"] = group["LON"].shift(-1)
    group["distance_km"] = group.apply(
        lambda row: haversine(row["LAT"], row["LON"], row["next_lat"], row["next_long"])
        if not np.isnan(row["next_lat"])
        else 0,
        axis=1,
    )
    return group.drop(columns=["next_lat", "next_long"])

# %%
segmented_trajectories_df = segmented_trajectories_df.groupby("MMSI").apply(calculate_distances).reset_index(drop=True)
segmented_trajectories_df.head()
# Out:
#          BaseDateTime       LAT       LON  SOG    COG  MMSI  SegmentID  \
# 0 2022-03-31 00:02:32  27.35372 -94.62546  0.4  228.6   111          0
# 1 2022-03-31 00:05:35  27.35372 -94.62550  0.6  219.8   111          0
# 2 2022-03-31 00:08:34  27.35377 -94.62556  0.2  221.7   111          0
# 3 2022-03-31 00:11:31  27.35380 -94.62557  0.3  105.0   111          0
# 4 2022-03-31 00:14:33  27.35365 -94.62542  0.3  173.4   111          0
#
#    duration_seconds           x            y            z  distance_km
# 0               0.0 -456.323030 -5640.208831  2927.363085     0.003950
# 1             183.0 -456.326968 -5640.208513  2927.363085     0.008126
# 2             179.0 -456.332668 -5640.205489  2927.368023     0.003479
# 3             177.0 -456.333529 -5640.203881  2927.370986     0.022308
# 4             182.0 -456.319381 -5640.212715  2927.356172     0.002224

# %% [markdown]
# ### Convert SOG to meters per second

# %%
segmented_trajectories_df['sog_to_meters_per_second'] =  segmented_trajectories_df.apply(lambda row: row['SOG'] * 0.514444, axis=1)
segmented_trajectories_df.head()
# Out:
#          BaseDateTime       LAT       LON  SOG    COG  MMSI  SegmentID  \
# 0 2022-03-31 00:02:32  27.35372 -94.62546  0.4  228.6   111          0
# 1 2022-03-31 00:05:35  27.35372 -94.62550  0.6  219.8   111          0
# 2 2022-03-31 00:08:34  27.35377 -94.62556  0.2  221.7   111          0
# 3 2022-03-31 00:11:31  27.35380 -94.62557  0.3  105.0   111          0
# 4 2022-03-31 00:14:33  27.35365 -94.62542  0.3  173.4   111          0
#
#    duration_seconds           x            y            z  distance_km  \
# 0               0.0 -456.323030 -5640.208831  2927.363085     0.003950
# 1             183.0 -456.326968 -5640.208513  2927.363085     0.008126
# 2             179.0 -456.332668 -5640.205489  2927.368023     0.003479
# 3             177.0 -456.333529 -5640.203881  2927.370986     0.022308
# 4             182.0 -456.319381 -5640.212715  2927.356172     0.002224
#
#    sog_to_meters_per_second
# 0                  0.205778
# 1                  0.308666
# 2                  0.102889
# 3                  0.154333
# 4                  0.154333

# %% [markdown]
# ### Convert COG to radians

# %%
segmented_trajectories_df['cog_to_radians'] = segmented_trajectories_df.apply(lambda row: np.radians(row['COG']) , axis=1)
segmented_trajectories_df.head()
# Out:
#          BaseDateTime       LAT       LON  SOG    COG  MMSI  SegmentID  \
# 0 2022-03-31 00:02:32  27.35372 -94.62546  0.4  228.6   111          0
# 1 2022-03-31 00:05:35  27.35372 -94.62550  0.6  219.8   111          0
# 2 2022-03-31 00:08:34  27.35377 -94.62556  0.2  221.7   111          0
# 3 2022-03-31 00:11:31  27.35380 -94.62557  0.3  105.0   111          0
# 4 2022-03-31 00:14:33  27.35365 -94.62542  0.3  173.4   111          0
#
#    duration_seconds           x            y            z  distance_km  \
# 0               0.0 -456.323030 -5640.208831  2927.363085     0.003950
# 1             183.0 -456.326968 -5640.208513  2927.363085     0.008126
# 2             179.0 -456.332668 -5640.205489  2927.368023     0.003479
# 3             177.0 -456.333529 -5640.203881  2927.370986     0.022308
# 4             182.0 -456.319381 -5640.212715  2927.356172     0.002224
#
#    sog_to_meters_per_second  cog_to_radians
# 0                  0.205778        3.989823
# 1                  0.308666        3.836234
# 2                  0.102889        3.869395
# 3                  0.154333        1.832596
# 4                  0.154333        3.026401

# %%
segmented_trajectories_df = segmented_trajectories_df[['x','y','z','duration_seconds', 'distance_km', 'sog_to_meters_per_second', 'cog_to_radians','SegmentID']]
segmented_trajectories_df.head()
# Out:
#             x            y            z  duration_seconds  distance_km  \
# 0 -456.323030 -5640.208831  2927.363085               0.0     0.003950
# 1 -456.326968 -5640.208513  2927.363085             183.0     0.008126
# 2 -456.332668 -5640.205489  2927.368023             179.0     0.003479
# 3 -456.333529 -5640.203881  2927.370986             177.0     0.022308
# 4 -456.319381 -5640.212715  2927.356172             182.0     0.002224
#
#    sog_to_meters_per_second  cog_to_radians  SegmentID
# 0                  0.205778        3.989823          0
# 1                  0.308666        3.836234          0
# 2                  0.102889        3.869395          0
# 3                  0.154333        1.832596          0
# 4                  0.154333        3.026401          0

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tqdm import tqdm


# Filter segments with insufficient rows
def filter_short_segments(data, window_size, prediction_horizon, group_col='SegmentID'):
    min_required_rows = window_size + prediction_horizon
    filtered_data = data.groupby(group_col).filter(lambda x: len(x) >= min_required_rows)
    print(f"Filtered data contains {len(filtered_data)} rows after removing short segments.")
    return filtered_data


# Prepare sequences with temporal features and SegmentID
def prepare_sequences(data, window_size, prediction_horizon,
                      group_col='SegmentID', time_col='BaseDateTime'):
    sequences = []
    unique_segments = sorted(data[group_col].unique())

    for segment in tqdm(unique_segments, desc="Processing Segments", unit="segment"):
        segment_data = data[data[group_col] == segment].reset_index(drop=True)
        num_rows = len(segment_data)
        # print(f"Segment {segment} has {num_rows} rows.")

        if num_rows < window_size + prediction_horizon:
            # print(f"Skipping segment {segment}: Not enough rows.")
            continue

        for start in range(num_rows - window_size - prediction_horizon + 1):
            x_window = segment_data.iloc[start:start+window_size]
            y_window = segment_data.iloc[start+window_size:start+window_size+prediction_horizon]
            sequences.append({
                'X': {
                    'x': x_window['x'].tolist(),
                    'y': x_window['y'].tolist(),
                    'z': x_window['z'].tolist(),
                    'duration_seconds': x_window['duration_seconds'].tolist(),
                    'distance_km': x_window['distance_km'].tolist(),
                    'sog_to_meters_per_second': x_window['sog_to_meters_per_second'].tolist(),
                    'cog_to_radians': x_window['cog_to_radians'].tolist(),
                    'SegmentID': x_window['SegmentID'].tolist(),
                },
                'Y': {
                   'x': x_window['x'].tolist(),
                    'y': x_window['y'].tolist(),
                    'z': x_window['z'].tolist(),
                    'duration_seconds': x_window['duration_seconds'].tolist(),
                    'distance_km': x_window['distance_km'].tolist(),
                    'sog_to_meters_per_second': x_window['sog_to_meters_per_second'].tolist(),
                    'cog_to_radians': x_window['cog_to_radians'].tolist(),
                    'SegmentID': x_window['SegmentID'].tolist(),
                }
            })
    return sequences


# Split data into train/val/test
def split_train_val_test(data, test_size=0.2, val_size=0.2):
    train_data, temp_data = train_test_split(data, test_size=test_size + val_size, random_state=42, shuffle=True)
    val_data, test_data = train_test_split(temp_data, test_size=test_size / (test_size + val_size), random_state=42, shuffle=True)
    return train_data, val_data, test_data


# Data preparation pipeline without scaling
def prepare_data_pipeline_no_scaling(data, window_size, prediction_horizon,
                                     test_size=0.2, val_size=0.2):
    # Filter short segments
    print("Filtering short segments...")
    data = filter_short_segments(data, window_size, prediction_horizon)

    # Split data
    print("Splitting data into train, validation, and test sets...")
    train_data, val_data, test_data = split_train_val_test(data, test_size, val_size)

    # Prepare sequences
    print("Preparing training sequences...")
    train_sequences = prepare_sequences(train_data, window_size, prediction_horizon)

    print("Preparing validation sequences...")
    val_sequences = prepare_sequences(val_data, window_size, prediction_horizon)

    print("Preparing test sequences...")
    test_sequences = prepare_sequences(test_data, window_size, prediction_horizon)

    return train_sequences, val_sequences, test_sequences

# Parameters
window_size = 5
prediction_horizon = 2
test_size = 0.2
val_size = 0.32


# Prepare data
train_sequences, val_sequences, test_sequences = prepare_data_pipeline_no_scaling(
    segmented_trajectories_df, window_size, prediction_horizon, test_size, val_size
)

print(f"Number of training sequences: {len(train_sequences)}")
print(f"Number of validation sequences: {len(val_sequences)}")
print(f"Number of test sequences: {len(test_sequences)}")
# Out:
# Filtering short segments...
# Filtered data contains 158270 rows after removing short segments.
# Splitting data into train, validation, and test sets...
# Preparing training sequences...
# Processing Segments: 100%|██████████| 15793/15793 [00:10<00:00, 1495.46segment/s]
# Preparing validation sequences...
# Processing Segments: 100%|██████████| 15486/15486 [00:07<00:00, 1998.48segment/s]
# Preparing test sequences...
# Processing Segments: 100%|██████████| 14065/14065 [00:07<00:00, 1811.13segment/s]
# Number of training sequences: 3084
# Number of validation sequences: 287
# Number of test sequences: 14

# %%
import numpy as np

def format_sequences(sequences, input_features, output_features, predicted_seq_len):
    """
    Format sequences for Seq2Seq model.

    Parameters:
    - sequences: List of dictionaries with 'X' and 'Y'.
    - input_features: List of feature names for inputs.
    - output_features: List of feature names for outputs.
    - predicted_seq_len: Length of the predicted sequence.

    Returns:
    - encoder_inputs: NumPy array of shape (num_sequences, input_seq_len, num_features).
    - decoder_inputs: NumPy array of shape (num_sequences, output_seq_len, num_features).
    - targets: NumPy array of shape (num_sequences, output_seq_len, num_targets).
    """
    encoder_inputs = []
    decoder_inputs = []
    targets = []

    for seq in sequences:
        # Extract input features for encoder
        encoder_input = np.array([seq['X'][feature] for feature in input_features]).T
        encoder_inputs.append(encoder_input)

        # Extract Y data for decoder inputs and targets
        y_data = np.array([seq['Y'][feature] for feature in input_features]).T  # Use input features for decoder inputs
        target_data = np.array([seq['Y'][feature] for feature in output_features]).T  # Use output features for targets

        # Ensure y_data has at least predicted_seq_len timesteps
        y_data = y_data[:predicted_seq_len, :] if len(y_data) >= predicted_seq_len else np.pad(
            y_data, ((0, predicted_seq_len - len(y_data)), (0, 0)), mode='constant'
        )

        target_data = target_data[:predicted_seq_len, :] if len(target_data) >= predicted_seq_len else np.pad(
            target_data, ((0, predicted_seq_len - len(target_data)), (0, 0)), mode='constant'
        )

        # Initialize decoder input and fill with previous steps
        decoder_input = np.zeros((predicted_seq_len, len(input_features)))
        decoder_input[:min(len(y_data) - 1, predicted_seq_len - 1), :] = y_data[:min(len(y_data) - 1, predicted_seq_len - 1), :]

        decoder_inputs.append(decoder_input)
        targets.append(target_data)

    return (
        np.array(encoder_inputs),
        np.array(decoder_inputs),
        np.array(targets)
    )


# Define the features for input and output
input_features = ['x', 'y', 'z', 'duration_seconds', 'distance_km',
                  'sog_to_meters_per_second', 'cog_to_radians']

output_features = ['x', 'y', 'z', 'duration_seconds',
                  'sog_to_meters_per_second', 'cog_to_radians']

predicted_seq_len = 2

# Format sequences for training, validation, and testing
train_enc_inputs, train_dec_inputs, train_targets = format_sequences(train_sequences, input_features, output_features, predicted_seq_len)
val_enc_inputs, val_dec_inputs, val_targets = format_sequences(val_sequences, input_features, output_features, predicted_seq_len)
test_enc_inputs, test_dec_inputs, test_targets = format_sequences(test_sequences, input_features, output_features, predicted_seq_len)

# Print the shapes to verify
print("Training data shapes:")
print(f"Encoder inputs: {train_enc_inputs.shape}, Decoder inputs: {train_dec_inputs.shape}, Targets: {train_targets.shape}")

# Check for NaN or Inf in your data
print("Checking training data for NaN or Inf...")
print(np.isnan(train_enc_inputs).any(), np.isinf(train_enc_inputs).any())
print(np.isnan(train_dec_inputs).any(), np.isinf(train_dec_inputs).any())
print(np.isnan(train_targets).any(), np.isinf(train_targets).any())
# Out:
# Training data shapes:
# Encoder inputs: (3084, 5, 7), Decoder inputs: (3084, 2, 7), Targets: (3084, 2, 6)
# Checking training data for NaN or Inf...
# False False
# False False
# False False

# %%
# import tensorflow as tf
# from tensorflow.keras.layers import (
#     Input, LSTM, Dense, Concatenate, Dropout, MultiHeadAttention,
#     Add, LayerNormalization, RepeatVector, Lambda, Conv1D, Bidirectional
# )
# from tensorflow.keras.models import Model
# from tensorflow.keras.optimizers import Adam

# def create_advanced_probabilistic_seq2seq(input_seq_len, output_seq_len, input_dim, output_dim, latent_dim):
#     """
#     Enhanced Probabilistic Seq2Seq Model for Time Series Forecasting with improvements for handling time series data.
#     """
#     # Encoder
#     encoder_inputs = Input(shape=(input_seq_len, input_dim), name="encoder_inputs")

#     # Temporal Convolutional Layers for better feature extraction in time series data
#     encoder_conv = Conv1D(filters=64, kernel_size=3, activation='relu', padding='same', name="encoder_conv")(encoder_inputs)
#     encoder_conv = Dropout(0.3, name="encoder_conv_dropout")(encoder_conv)

#     # Bidirectional LSTM for Encoder to capture patterns from both directions
#     encoder_lstm = Bidirectional(LSTM(latent_dim, return_sequences=True, return_state=True, name="encoder_lstm"))
#     encoder_outputs, forward_h, forward_c, backward_h, backward_c = encoder_lstm(encoder_conv)  # Adjusted unpacking

#     # Combine forward and backward states to form initial state for decoder
#     state_h = Concatenate()([forward_h, backward_h])
#     state_c = Concatenate()([forward_c, backward_c])

#     # Multi-Head Attention for Encoder
#     multi_head_attention = MultiHeadAttention(num_heads=4, key_dim=latent_dim, name="multi_head_attention")
#     encoder_attention = multi_head_attention(encoder_outputs, encoder_outputs)  # Query and value are the same
#     encoder_attention = LayerNormalization(name="encoder_attention_norm")(encoder_attention)

#     # Decoder
#     decoder_inputs = Input(shape=(output_seq_len, input_dim), name="decoder_inputs")

#     # Convolutional Layer in Decoder
#     decoder_conv = Conv1D(filters=64, kernel_size=3, activation='relu', padding='same', name="decoder_conv")(decoder_inputs)
#     decoder_conv = Dropout(0.3, name="decoder_conv_dropout")(decoder_conv)

#     # Decoder LSTM, using encoder states for initialization
#     decoder_lstm = LSTM(latent_dim * 2, return_sequences=True, return_state=True, name="decoder_lstm")
#     decoder_outputs, _, _ = decoder_lstm(decoder_conv, initial_state=[state_h, state_c])

#     # Ensure that the attention mechanism has compatible shapes (query and value)
#     attention_context = multi_head_attention(decoder_outputs, encoder_attention)  # Using encoder attention in decoder
#     attention_context = LayerNormalization(name="decoder_attention_norm")(attention_context)
#     attention_context = Lambda(lambda x: tf.reduce_mean(x, axis=1), name="summarize_attention")(attention_context)

#     # Ensure Attention Context and Decoder Outputs have compatible dimensions
#     attention_context_repeated = RepeatVector(output_seq_len)(attention_context)  # Repeat to match output_seq_len
#     attention_context_repeated = tf.keras.layers.Reshape((output_seq_len, latent_dim * 2))(attention_context_repeated)

#     # Merge Attention Context with Decoder Outputs
#     merged_context = Concatenate(axis=-1)([decoder_outputs, attention_context_repeated])

#     # Dropout and Output Layers
#     dropout = Dropout(0.4, name="decoder_dropout")(merged_context)
#     output_mean = Dense(output_dim, activation="linear", kernel_regularizer=tf.keras.regularizers.l2(1e-4),
#                         name="mean_output")(dropout)
#     output_std = Dense(output_dim, activation="softplus", kernel_regularizer=tf.keras.regularizers.l2(1e-4),
#                        name="std_output")(dropout)

#     # Combine Outputs
#     outputs = Concatenate(name="probabilistic_outputs")([output_mean, output_std])

#     # Define the Model
#     model = Model(inputs=[encoder_inputs, decoder_inputs], outputs=outputs, name="enhanced_probabilistic_seq2seq_model")

#     # Custom Loss Function (Negative Log-Likelihood)
#     def nll_loss(y_true, y_pred):
#         mean = y_pred[..., :output_dim]
#         std = y_pred[..., output_dim:]
#         dist = tf.compat.v1.distributions.Normal(loc=mean, scale=std)
#         return -tf.reduce_mean(dist.log_prob(y_true))

#     # Probabilistic Evaluation Metric: CRPS
#     def crps_metric(y_true, y_pred):
#         mean = y_pred[..., :output_dim]
#         std = y_pred[..., output_dim:]
#         return tf.reduce_mean((y_true - mean) ** 2 / (2 * std ** 2) + tf.math.log(std))

#     # Adjusted R² Metric
#     def adjusted_r2_score(y_true, y_pred):
#         mean = y_pred[..., :output_dim]
#         ss_res = tf.reduce_sum(tf.square(y_true - mean), axis=-1)
#         ss_tot = tf.reduce_sum(tf.square(y_true - tf.reduce_mean(y_true, axis=-1, keepdims=True)), axis=-1)
#         r2 = 1 - (ss_res / (ss_tot + tf.keras.backend.epsilon()))

#         # Number of samples (batch size)
#         n = tf.cast(tf.shape(y_true)[0], tf.float32)

#         # Number of predictors (features)
#         p = tf.cast(output_dim, tf.float32)

#         # Adjusted R²
#         adjusted_r2 = 1 - ((1 - r2) * (n - 1)) / (n - p - 1 + tf.keras.backend.epsilon())
#         return adjusted_r2

#     # Optimizer
#     optimizer = Adam(learning_rate=0.01)

#     # Compile the Model
#     model.compile(optimizer=optimizer, loss=nll_loss, metrics=[crps_metric, adjusted_r2_score])

#     return model

# %%
import tensorflow as tf
from tensorflow.keras.layers import (
    Input, LSTM, Dense, Concatenate, Dropout, MultiHeadAttention,
    LayerNormalization, RepeatVector, Lambda, Conv1D, Bidirectional
)
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

def create_advanced_probabilistic_seq2seq(input_seq_len, output_seq_len, input_dim, output_dim, latent_dim):
    """
    Enhanced Probabilistic Seq2Seq Model for Time Series Forecasting.
    """
    # Encoder
    encoder_inputs = Input(shape=(input_seq_len, input_dim), name="encoder_inputs")

    # Temporal Convolution for feature extraction
    encoder_conv = Conv1D(filters=64, kernel_size=3, activation='relu', padding='same', name="encoder_conv")(encoder_inputs)
    encoder_conv = Dropout(0.3, name="encoder_conv_dropout")(encoder_conv)

    # Bidirectional LSTM Encoder
    encoder_lstm = Bidirectional(LSTM(latent_dim, return_sequences=True, return_state=True, name="encoder_lstm"))
    encoder_outputs, forward_h, forward_c, backward_h, backward_c = encoder_lstm(encoder_conv)

    # Combine forward and backward states
    state_h = Concatenate()([forward_h, backward_h])
    state_c = Concatenate()([forward_c, backward_c])

    # Multi-Head Attention for Encoder
    multi_head_attention = MultiHeadAttention(num_heads=4, key_dim=latent_dim, name="multi_head_attention")
    encoder_attention = multi_head_attention(encoder_outputs, encoder_outputs)
    encoder_attention = LayerNormalization(name="encoder_attention_norm")(encoder_attention)

    # Decoder
    decoder_inputs = Input(shape=(output_seq_len, input_dim), name="decoder_inputs")

    # Convolution in Decoder
    decoder_conv = Conv1D(filters=64, kernel_size=3, activation='relu', padding='same', name="decoder_conv")(decoder_inputs)
    decoder_conv = Dropout(0.3, name="decoder_conv_dropout")(decoder_conv)

    # LSTM Decoder using encoder states
    decoder_lstm = LSTM(latent_dim * 2, return_sequences=True, return_state=True, name="decoder_lstm")
    decoder_outputs, _, _ = decoder_lstm(decoder_conv, initial_state=[state_h, state_c])

    # Attention Mechanism in Decoder
    attention_context = multi_head_attention(decoder_outputs, encoder_attention)
    attention_context = LayerNormalization(name="decoder_attention_norm")(attention_context)
    attention_context = Lambda(lambda x: tf.reduce_mean(x, axis=1), name="summarize_attention")(attention_context)

    # Repeat Attention Context to match output sequence length
    attention_context_repeated = RepeatVector(output_seq_len)(attention_context)
    attention_context_repeated = tf.keras.layers.Reshape((output_seq_len, latent_dim * 2))(attention_context_repeated)

    # Merge Attention Context with Decoder Outputs
    merged_context = Concatenate(axis=-1)([decoder_outputs, attention_context_repeated])

    # Dropout before final output layers
    dropout = Dropout(0.4, name="decoder_dropout")(merged_context)

    # Mean output prediction
    output_mean = Dense(output_dim, activation="linear", kernel_regularizer=tf.keras.regularizers.l2(1e-4),
                        name="mean_output")(dropout)

    # Standard deviation output prediction (ensuring it never gets too small)
    output_std = Dense(output_dim, activation=lambda x: tf.nn.softplus(x) + 1e-6,
                       kernel_regularizer=tf.keras.regularizers.l2(1e-4),
                       name="std_output")(dropout)

    # Final output (concatenating mean and std)
    outputs = Concatenate(name="probabilistic_outputs")([output_mean, output_std])

    # Define Model
    model = Model(inputs=[encoder_inputs, decoder_inputs], outputs=outputs, name="enhanced_probabilistic_seq2seq_model")

    # Custom Negative Log-Likelihood (NLL) Loss
    def nll_loss(y_true, y_pred):
        mean = y_pred[..., :output_dim]
        std = y_pred[..., output_dim:]
        dist = tf.compat.v1.distributions.Normal(loc=mean, scale=std)
        return -tf.reduce_mean(dist.log_prob(y_true))

    # Continuous Ranked Probability Score (CRPS) Metric
    def crps_metric(y_true, y_pred):
        mean = y_pred[..., :output_dim]
        std = y_pred[..., output_dim:]
        return tf.reduce_mean((y_true - mean) ** 2 / (2 * std ** 2) + tf.math.log(std + 1e-6))  # Avoid log(0)

    # Adjusted R² Score (Fixed NaN Issue)
    def adjusted_r2_score(y_true, y_pred):
        mean = y_pred[..., :output_dim]
        ss_res = tf.reduce_sum(tf.square(y_true - mean), axis=-1)
        ss_tot = tf.reduce_sum(tf.square(y_true - tf.reduce_mean(y_true, axis=-1, keepdims=True)), axis=-1)

        r2 = 1 - (ss_res / (ss_tot + 1e-8))  # Avoid divide-by-zero

        n = tf.cast(tf.shape(y_true)[0], tf.float32)
        p = tf.cast(output_dim, tf.float32)

        adjusted_r2 = 1 - ((1 - r2) * (n - 1)) / (tf.maximum(n - p - 1, 1))  # Ensure denominator is never zero
        return adjusted_r2

    # Optimizer with Gradient Clipping
    optimizer = Adam(learning_rate=0.001, clipnorm=1.0)

    # Compile the Model
    model.compile(optimizer=optimizer, loss=nll_loss, metrics=[crps_metric, adjusted_r2_score])

    return model

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# Hyperparameters
input_seq_len = 5  # Input sequence length
output_seq_len = 2  # Output sequence length
latent_dim = 64  # Number of LSTM units
input_dim = len(input_features)  # Number of input features
output_dim = len(output_features)  # Number of output features

# Create the model
model = create_advanced_probabilistic_seq2seq(input_seq_len, output_seq_len, input_dim, output_dim, latent_dim)

# Callbacks
lr_scheduler = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=5, verbose=1)
early_stopping = EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True, verbose=1)

# Train the model
print("Training the model...")
history = model.fit(
    [train_enc_inputs, train_dec_inputs],
    train_targets,
    validation_data=([val_enc_inputs, val_dec_inputs], val_targets),
    batch_size=32,
    epochs=100,
    callbacks=[lr_scheduler, early_stopping],
    verbose=1
)

# Save the Model
model.save_weights("prob_attention_lstm.weights.h5")
print("Model saved successfully.")
# Out:
# Training the model...
# Epoch 1/100
# WARNING:tensorflow:From <ipython-input-19-bfd44c643a87>:78: Normal.__init__ (from tensorflow.python.ops.distributions.normal) is deprecated and will be removed after 2019-01-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.distributions`.
# WARNING:tensorflow:From /usr/local/lib/python3.11/dist-packages/tensorflow/python/ops/distributions/normal.py:149: Distribution.__init__ (from tensorflow.python.ops.distributions.distribution) is deprecated and will be removed after 2019-01-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.distributions`.
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 17s 52ms/step - adjusted_r2_score: -0.2634 - crps_metric: 4676492.5000 - loss: 4676616.5000 - val_adjusted_r2_score: -0.2544 - val_crps_metric: 3459.1748 - val_loss: 3459.5344 - learning_rate: 0.0010
# Epoch 2/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step - adjusted_r2_score: -0.2491 - crps_metric: 2516.6123 - loss: 2517.6650 - val_adjusted_r2_score: -0.2363 - val_crps_metric: 752.6369 - val_loss: 753.4717 - learning_rate: 0.0010
# Epoch 3/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - adjusted_r2_score: -0.2305 - crps_metric: 611.0995 - loss: 612.0521 - val_adjusted_r2_score: -0.2155 - val_crps_metric: 290.6941 - val_loss: 291.5939 - learning_rate: 0.0010
# Epoch 4/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - adjusted_r2_score: -0.2091 - crps_metric: 248.9848 - loss: 249.9296 - val_adjusted_r2_score: -0.1936 - val_crps_metric: 145.5576 - val_loss: 146.4848 - learning_rate: 0.0010
# Epoch 5/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - adjusted_r2_score: -0.1878 - crps_metric: 129.0702 - loss: 130.0195 - val_adjusted_r2_score: -0.1729 - val_crps_metric: 84.4842 - val_loss: 85.4288 - learning_rate: 0.0010
# Epoch 6/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - adjusted_r2_score: -0.1680 - crps_metric: 76.6156 - loss: 77.5731 - val_adjusted_r2_score: -0.1551 - val_crps_metric: 54.2873 - val_loss: 55.2452 - learning_rate: 0.0010
# Epoch 7/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - adjusted_r2_score: -0.1505 - crps_metric: 50.7524 - loss: 51.7194 - val_adjusted_r2_score: -0.1393 - val_crps_metric: 37.6564 - val_loss: 38.6266 - learning_rate: 0.0010
# Epoch 8/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - adjusted_r2_score: -0.1347 - crps_metric: 35.4220 - loss: 36.3986 - val_adjusted_r2_score: -0.1246 - val_crps_metric: 27.8216 - val_loss: 28.8033 - learning_rate: 0.0010
# Epoch 9/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - adjusted_r2_score: -0.1209 - crps_metric: 26.3106 - loss: 27.2971 - val_adjusted_r2_score: -0.1109 - val_crps_metric: 21.5596 - val_loss: 22.5520 - learning_rate: 0.0010
# Epoch 10/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - adjusted_r2_score: -0.1075 - crps_metric: 20.8461 - loss: 21.8429 - val_adjusted_r2_score: -0.0989 - val_crps_metric: 17.8630 - val_loss: 18.8662 - learning_rate: 0.0010
# Epoch 11/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - adjusted_r2_score: -0.0953 - crps_metric: 17.2360 - loss: 18.2426 - val_adjusted_r2_score: -0.0886 - val_crps_metric: 15.4667 - val_loss: 16.4801 - learning_rate: 0.0010
# Epoch 12/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 61ms/step - adjusted_r2_score: -0.0854 - crps_metric: 14.9392 - loss: 15.9552 - val_adjusted_r2_score: -0.0795 - val_crps_metric: 13.7405 - val_loss: 14.7629 - learning_rate: 0.0010
# Epoch 13/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - adjusted_r2_score: -0.0771 - crps_metric: 13.4579 - loss: 14.4827 - val_adjusted_r2_score: -0.0709 - val_crps_metric: 12.4400 - val_loss: 13.4708 - learning_rate: 0.0010
# Epoch 14/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 62ms/step - adjusted_r2_score: -0.0686 - crps_metric: 12.2450 - loss: 13.2785 - val_adjusted_r2_score: -0.0632 - val_crps_metric: 11.6394 - val_loss: 12.6786 - learning_rate: 0.0010
# Epoch 15/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - adjusted_r2_score: -0.0611 - crps_metric: 11.3830 - loss: 12.4241 - val_adjusted_r2_score: -0.0556 - val_crps_metric: 10.9139 - val_loss: 11.9605 - learning_rate: 0.0010
# Epoch 16/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 58ms/step - adjusted_r2_score: -0.0526 - crps_metric: 10.6599 - loss: 11.7084 - val_adjusted_r2_score: -0.0485 - val_crps_metric: 10.3771 - val_loss: 11.4310 - learning_rate: 0.0010
# Epoch 17/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - adjusted_r2_score: -0.0464 - crps_metric: 10.1663 - loss: 11.2218 - val_adjusted_r2_score: -0.0413 - val_crps_metric: 9.9630 - val_loss: 11.0238 - learning_rate: 0.0010
# Epoch 18/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - adjusted_r2_score: -0.0398 - crps_metric: 9.6305 - loss: 10.6924 - val_adjusted_r2_score: -0.0345 - val_crps_metric: 9.5579 - val_loss: 10.6250 - learning_rate: 0.0010
# Epoch 19/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - adjusted_r2_score: -0.0326 - crps_metric: 9.2933 - loss: 10.3614 - val_adjusted_r2_score: -0.0278 - val_crps_metric: 9.1972 - val_loss: 10.2699 - learning_rate: 0.0010
# Epoch 20/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - adjusted_r2_score: -0.0255 - crps_metric: 8.9941 - loss: 10.0678 - val_adjusted_r2_score: -0.0212 - val_crps_metric: 8.8776 - val_loss: 9.9557 - learning_rate: 0.0010
# Epoch 21/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 63ms/step - adjusted_r2_score: -0.0195 - crps_metric: 8.7856 - loss: 9.8649 - val_adjusted_r2_score: -0.0147 - val_crps_metric: 8.5716 - val_loss: 9.6546 - learning_rate: 0.0010
# Epoch 22/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - adjusted_r2_score: -0.0132 - crps_metric: 8.5304 - loss: 9.6147 - val_adjusted_r2_score: -0.0082 - val_crps_metric: 8.4350 - val_loss: 9.5233 - learning_rate: 0.0010
# Epoch 23/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 61ms/step - adjusted_r2_score: -0.0059 - crps_metric: 8.2945 - loss: 9.3839 - val_adjusted_r2_score: -0.0016 - val_crps_metric: 8.3443 - val_loss: 9.4382 - learning_rate: 0.0010
# Epoch 24/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - adjusted_r2_score: -6.5131e-04 - crps_metric: 8.1448 - loss: 9.2392 - val_adjusted_r2_score: 0.0047 - val_crps_metric: 8.0693 - val_loss: 9.1674 - learning_rate: 0.0010
# Epoch 25/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - adjusted_r2_score: 0.0072 - crps_metric: 7.9435 - loss: 9.0425 - val_adjusted_r2_score: 0.0112 - val_crps_metric: 7.9255 - val_loss: 9.0285 - learning_rate: 0.0010
# Epoch 26/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - adjusted_r2_score: 0.0132 - crps_metric: 7.8040 - loss: 8.9078 - val_adjusted_r2_score: 0.0173 - val_crps_metric: 7.8336 - val_loss: 8.9410 - learning_rate: 0.0010
# Epoch 27/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - adjusted_r2_score: 0.0194 - crps_metric: 7.6379 - loss: 8.7459 - val_adjusted_r2_score: 0.0239 - val_crps_metric: 7.6473 - val_loss: 8.7590 - learning_rate: 0.0010
# Epoch 28/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - adjusted_r2_score: 0.0256 - crps_metric: 7.4746 - loss: 8.5870 - val_adjusted_r2_score: 0.0300 - val_crps_metric: 7.5548 - val_loss: 8.6706 - learning_rate: 0.0010
# Epoch 29/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - adjusted_r2_score: 0.0316 - crps_metric: 7.3782 - loss: 8.4948 - val_adjusted_r2_score: 0.0363 - val_crps_metric: 7.4475 - val_loss: 8.5676 - learning_rate: 0.0010
# Epoch 30/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - adjusted_r2_score: 0.0381 - crps_metric: 7.2960 - loss: 8.4167 - val_adjusted_r2_score: 0.0429 - val_crps_metric: 7.3513 - val_loss: 8.4756 - learning_rate: 0.0010
# Epoch 31/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - adjusted_r2_score: 0.0448 - crps_metric: 7.2034 - loss: 8.3283 - val_adjusted_r2_score: 0.0494 - val_crps_metric: 7.3375 - val_loss: 8.4659 - learning_rate: 0.0010
# Epoch 32/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - adjusted_r2_score: 0.0513 - crps_metric: 7.0734 - loss: 8.2021 - val_adjusted_r2_score: 0.0561 - val_crps_metric: 7.2005 - val_loss: 8.3327 - learning_rate: 0.0010
# Epoch 33/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 64ms/step - adjusted_r2_score: 0.0580 - crps_metric: 6.9866 - loss: 8.1192 - val_adjusted_r2_score: 0.0621 - val_crps_metric: 7.2434 - val_loss: 8.3797 - learning_rate: 0.0010
# Epoch 34/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - adjusted_r2_score: 0.0640 - crps_metric: 6.9578 - loss: 8.0941 - val_adjusted_r2_score: 0.0677 - val_crps_metric: 7.0000 - val_loss: 8.1393 - learning_rate: 0.0010
# Epoch 35/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - adjusted_r2_score: 0.0689 - crps_metric: 6.8728 - loss: 8.0127 - val_adjusted_r2_score: 0.0761 - val_crps_metric: 7.1319 - val_loss: 8.2757 - learning_rate: 0.0010
# Epoch 36/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - adjusted_r2_score: 0.0783 - crps_metric: 6.8322 - loss: 7.9758 - val_adjusted_r2_score: 0.0829 - val_crps_metric: 6.9025 - val_loss: 8.0491 - learning_rate: 0.0010
# Epoch 37/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - adjusted_r2_score: 0.0826 - crps_metric: 6.7318 - loss: 7.8788 - val_adjusted_r2_score: 0.0890 - val_crps_metric: 6.9663 - val_loss: 8.1166 - learning_rate: 0.0010
# Epoch 38/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - adjusted_r2_score: 0.0905 - crps_metric: 6.6840 - loss: 7.8342 - val_adjusted_r2_score: 0.0959 - val_crps_metric: 6.7301 - val_loss: 7.8829 - learning_rate: 0.0010
# Epoch 39/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - adjusted_r2_score: 0.0975 - crps_metric: 6.6240 - loss: 7.7775 - val_adjusted_r2_score: 0.1031 - val_crps_metric: 6.6676 - val_loss: 7.8236 - learning_rate: 0.0010
# Epoch 40/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - adjusted_r2_score: 0.1045 - crps_metric: 6.5955 - loss: 7.7521 - val_adjusted_r2_score: 0.1090 - val_crps_metric: 6.6437 - val_loss: 7.8029 - learning_rate: 0.0010
# Epoch 41/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 61ms/step - adjusted_r2_score: 0.1113 - crps_metric: 6.5148 - loss: 7.6745 - val_adjusted_r2_score: 0.1166 - val_crps_metric: 6.5865 - val_loss: 7.7487 - learning_rate: 0.0010
# Epoch 42/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 9s 53ms/step - adjusted_r2_score: 0.1187 - crps_metric: 6.5307 - loss: 7.6935 - val_adjusted_r2_score: 0.1236 - val_crps_metric: 6.6246 - val_loss: 7.7899 - learning_rate: 0.0010
# Epoch 43/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - adjusted_r2_score: 0.1248 - crps_metric: 6.4876 - loss: 7.6532 - val_adjusted_r2_score: 0.1305 - val_crps_metric: 6.5725 - val_loss: 7.7407 - learning_rate: 0.0010
# Epoch 44/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 11s 61ms/step - adjusted_r2_score: 0.1324 - crps_metric: 6.3617 - loss: 7.5301 - val_adjusted_r2_score: 0.1370 - val_crps_metric: 6.5516 - val_loss: 7.7226 - learning_rate: 0.0010
# Epoch 45/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 9s 51ms/step - adjusted_r2_score: 0.1378 - crps_metric: 6.3554 - loss: 7.5266 - val_adjusted_r2_score: 0.1447 - val_crps_metric: 6.5082 - val_loss: 7.6820 - learning_rate: 0.0010
# Epoch 46/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - adjusted_r2_score: 0.1465 - crps_metric: 6.3332 - loss: 7.5072 - val_adjusted_r2_score: 0.1519 - val_crps_metric: 7.0753 - val_loss: 8.2536 - learning_rate: 0.0010
# Epoch 47/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - adjusted_r2_score: 0.1540 - crps_metric: 6.2993 - loss: 7.4761 - val_adjusted_r2_score: 0.1594 - val_crps_metric: 6.5816 - val_loss: 7.7615 - learning_rate: 0.0010
# Epoch 48/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - adjusted_r2_score: 0.1600 - crps_metric: 6.2558 - loss: 7.4355 - val_adjusted_r2_score: 0.1670 - val_crps_metric: 6.6158 - val_loss: 7.7987 - learning_rate: 0.0010
# Epoch 49/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - adjusted_r2_score: 0.1690 - crps_metric: 6.1923 - loss: 7.3748 - val_adjusted_r2_score: 0.1746 - val_crps_metric: 6.5498 - val_loss: 7.7352 - learning_rate: 0.0010
# Epoch 50/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - adjusted_r2_score: 0.1759 - crps_metric: 6.1816 - loss: 7.3667 - val_adjusted_r2_score: 0.1816 - val_crps_metric: 6.3280 - val_loss: 7.5154 - learning_rate: 0.0010
# Epoch 51/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - adjusted_r2_score: 0.1829 - crps_metric: 6.1737 - loss: 7.3612 - val_adjusted_r2_score: 0.1891 - val_crps_metric: 6.2922 - val_loss: 7.4818 - learning_rate: 0.0010
# Epoch 52/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - adjusted_r2_score: 0.1897 - crps_metric: 6.1668 - loss: 7.3565 - val_adjusted_r2_score: 0.1967 - val_crps_metric: 6.4385 - val_loss: 7.6309 - learning_rate: 0.0010
# Epoch 53/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - adjusted_r2_score: 0.1979 - crps_metric: 6.1162 - loss: 7.3083 - val_adjusted_r2_score: 0.2024 - val_crps_metric: 6.2129 - val_loss: 7.4071 - learning_rate: 0.0010
# Epoch 54/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - adjusted_r2_score: 0.2044 - crps_metric: 6.0723 - loss: 7.2667 - val_adjusted_r2_score: 0.2110 - val_crps_metric: 6.1915 - val_loss: 7.3879 - learning_rate: 0.0010
# Epoch 55/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - adjusted_r2_score: 0.2116 - crps_metric: 6.0798 - loss: 7.2765 - val_adjusted_r2_score: 0.2197 - val_crps_metric: 6.4780 - val_loss: 7.6777 - learning_rate: 0.0010
# Epoch 56/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - adjusted_r2_score: 0.2208 - crps_metric: 6.0162 - loss: 7.2151 - val_adjusted_r2_score: 0.2264 - val_crps_metric: 6.2666 - val_loss: 7.4677 - learning_rate: 0.0010
# Epoch 57/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - adjusted_r2_score: 0.2293 - crps_metric: 6.0365 - loss: 7.2373 - val_adjusted_r2_score: 0.2356 - val_crps_metric: 6.1132 - val_loss: 7.3158 - learning_rate: 0.0010
# Epoch 58/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - adjusted_r2_score: 0.2378 - crps_metric: 5.9968 - loss: 7.1994 - val_adjusted_r2_score: 0.2435 - val_crps_metric: 6.1176 - val_loss: 7.3223 - learning_rate: 0.0010
# Epoch 59/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - adjusted_r2_score: 0.2444 - crps_metric: 6.0031 - loss: 7.2079 - val_adjusted_r2_score: 0.2522 - val_crps_metric: 6.0998 - val_loss: 7.3063 - learning_rate: 0.0010
# Epoch 60/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - adjusted_r2_score: 0.2527 - crps_metric: 5.9480 - loss: 7.1546 - val_adjusted_r2_score: 0.2591 - val_crps_metric: 6.0967 - val_loss: 7.3050 - learning_rate: 0.0010
# Epoch 61/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - adjusted_r2_score: 0.2596 - crps_metric: 5.9509 - loss: 7.1593 - val_adjusted_r2_score: 0.2672 - val_crps_metric: 6.0750 - val_loss: 7.2850 - learning_rate: 0.0010
# Epoch 62/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - adjusted_r2_score: 0.2690 - crps_metric: 5.9662 - loss: 7.1762 - val_adjusted_r2_score: 0.2750 - val_crps_metric: 5.9900 - val_loss: 7.2011 - learning_rate: 0.0010
# Epoch 63/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - adjusted_r2_score: 0.2785 - crps_metric: 5.8920 - loss: 7.1033 - val_adjusted_r2_score: 0.2839 - val_crps_metric: 5.9645 - val_loss: 7.1771 - learning_rate: 0.0010
# Epoch 64/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 61ms/step - adjusted_r2_score: 0.2841 - crps_metric: 5.9171 - loss: 7.1297 - val_adjusted_r2_score: 0.2912 - val_crps_metric: 6.1190 - val_loss: 7.3335 - learning_rate: 0.0010
# Epoch 65/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - adjusted_r2_score: 0.2918 - crps_metric: 5.8808 - loss: 7.0950 - val_adjusted_r2_score: 0.2983 - val_crps_metric: 6.2913 - val_loss: 7.5076 - learning_rate: 0.0010
# Epoch 66/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - adjusted_r2_score: 0.2967 - crps_metric: 5.8771 - loss: 7.0928 - val_adjusted_r2_score: 0.3075 - val_crps_metric: 6.0216 - val_loss: 7.2388 - learning_rate: 0.0010
# Epoch 67/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - adjusted_r2_score: 0.3096 - crps_metric: 5.8788 - loss: 7.0959 - val_adjusted_r2_score: 0.3174 - val_crps_metric: 5.9526 - val_loss: 7.1707 - learning_rate: 0.0010
# Epoch 68/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - adjusted_r2_score: 0.3190 - crps_metric: 5.8566 - loss: 7.0748 - val_adjusted_r2_score: 0.3182 - val_crps_metric: 5.9692 - val_loss: 7.1885 - learning_rate: 0.0010
# Epoch 69/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - adjusted_r2_score: 0.3220 - crps_metric: 5.8545 - loss: 7.0737 - val_adjusted_r2_score: 0.3354 - val_crps_metric: 6.0948 - val_loss: 7.3155 - learning_rate: 0.0010
# Epoch 70/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - adjusted_r2_score: 0.3358 - crps_metric: 5.8634 - loss: 7.0836 - val_adjusted_r2_score: 0.3434 - val_crps_metric: 6.2497 - val_loss: 7.4718 - learning_rate: 0.0010
# Epoch 71/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - adjusted_r2_score: 0.3439 - crps_metric: 5.8028 - loss: 7.0238 - val_adjusted_r2_score: 0.3500 - val_crps_metric: 6.0062 - val_loss: 7.2283 - learning_rate: 0.0010
# Epoch 72/100
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - adjusted_r2_score: 0.3522 - crps_metric: 5.7935 - loss: 7.0153
# Epoch 72: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - adjusted_r2_score: 0.3522 - crps_metric: 5.7938 - loss: 7.0156 - val_adjusted_r2_score: 0.3574 - val_crps_metric: 6.0171 - val_loss: 7.2402 - learning_rate: 0.0010
# Epoch 73/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 9s 52ms/step - adjusted_r2_score: 0.3571 - crps_metric: 5.7741 - loss: 6.9966 - val_adjusted_r2_score: 0.3650 - val_crps_metric: 6.0180 - val_loss: 7.2414 - learning_rate: 5.0000e-04
# Epoch 74/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - adjusted_r2_score: 0.3662 - crps_metric: 5.7908 - loss: 7.0135 - val_adjusted_r2_score: 0.3702 - val_crps_metric: 5.9893 - val_loss: 7.2129 - learning_rate: 5.0000e-04
# Epoch 75/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - adjusted_r2_score: 0.3708 - crps_metric: 5.7548 - loss: 6.9778 - val_adjusted_r2_score: 0.3744 - val_crps_metric: 5.8991 - val_loss: 7.1227 - learning_rate: 5.0000e-04
# Epoch 76/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - adjusted_r2_score: 0.3747 - crps_metric: 5.7926 - loss: 7.0159 - val_adjusted_r2_score: 0.3802 - val_crps_metric: 5.8901 - val_loss: 7.1139 - learning_rate: 5.0000e-04
# Epoch 77/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - adjusted_r2_score: 0.3781 - crps_metric: 5.8120 - loss: 7.0356 - val_adjusted_r2_score: 0.3851 - val_crps_metric: 6.0860 - val_loss: 7.3106 - learning_rate: 5.0000e-04
# Epoch 78/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 9s 51ms/step - adjusted_r2_score: 0.3854 - crps_metric: 5.7411 - loss: 6.9649 - val_adjusted_r2_score: 0.3899 - val_crps_metric: 5.8686 - val_loss: 7.0928 - learning_rate: 5.0000e-04
# Epoch 79/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - adjusted_r2_score: 0.3880 - crps_metric: 5.7364 - loss: 6.9603 - val_adjusted_r2_score: 0.3943 - val_crps_metric: 5.8818 - val_loss: 7.1061 - learning_rate: 5.0000e-04
# Epoch 80/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 9s 51ms/step - adjusted_r2_score: 0.3935 - crps_metric: 5.7689 - loss: 6.9929 - val_adjusted_r2_score: 0.3990 - val_crps_metric: 5.9233 - val_loss: 7.1478 - learning_rate: 5.0000e-04
# Epoch 81/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - adjusted_r2_score: 0.3996 - crps_metric: 5.7157 - loss: 6.9398 - val_adjusted_r2_score: 0.4059 - val_crps_metric: 5.9131 - val_loss: 7.1378 - learning_rate: 5.0000e-04
# Epoch 82/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - adjusted_r2_score: 0.4030 - crps_metric: 5.7292 - loss: 6.9535 - val_adjusted_r2_score: 0.4113 - val_crps_metric: 5.9429 - val_loss: 7.1678 - learning_rate: 5.0000e-04
# Epoch 83/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - adjusted_r2_score: 0.4103 - crps_metric: 5.6884 - loss: 6.9127 - val_adjusted_r2_score: 0.4154 - val_crps_metric: 5.8485 - val_loss: 7.0731 - learning_rate: 5.0000e-04
# Epoch 84/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - adjusted_r2_score: 0.4153 - crps_metric: 5.7112 - loss: 6.9353 - val_adjusted_r2_score: 0.4208 - val_crps_metric: 5.8737 - val_loss: 7.0985 - learning_rate: 5.0000e-04
# Epoch 85/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - adjusted_r2_score: 0.4188 - crps_metric: 5.7501 - loss: 6.9745 - val_adjusted_r2_score: 0.4255 - val_crps_metric: 5.9461 - val_loss: 7.1711 - learning_rate: 5.0000e-04
# Epoch 86/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - adjusted_r2_score: 0.4253 - crps_metric: 5.7789 - loss: 7.0032 - val_adjusted_r2_score: 0.4336 - val_crps_metric: 5.9378 - val_loss: 7.1627 - learning_rate: 5.0000e-04
# Epoch 87/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - adjusted_r2_score: 0.4305 - crps_metric: 5.7469 - loss: 6.9712 - val_adjusted_r2_score: 0.4382 - val_crps_metric: 6.1316 - val_loss: 7.3569 - learning_rate: 5.0000e-04
# Epoch 88/100
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - adjusted_r2_score: 0.4363 - crps_metric: 5.7705 - loss: 6.9947
# Epoch 88: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 10s 56ms/step - adjusted_r2_score: 0.4362 - crps_metric: 5.7693 - loss: 6.9935 - val_adjusted_r2_score: 0.4440 - val_crps_metric: 5.8687 - val_loss: 7.0933 - learning_rate: 5.0000e-04
# Epoch 89/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - adjusted_r2_score: 0.4403 - crps_metric: 5.7167 - loss: 6.9409 - val_adjusted_r2_score: 0.4479 - val_crps_metric: 5.8412 - val_loss: 7.0656 - learning_rate: 2.5000e-04
# Epoch 90/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - adjusted_r2_score: 0.4478 - crps_metric: 5.7012 - loss: 6.9252 - val_adjusted_r2_score: 0.4516 - val_crps_metric: 5.8549 - val_loss: 7.0792 - learning_rate: 2.5000e-04
# Epoch 91/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - adjusted_r2_score: 0.4512 - crps_metric: 5.6850 - loss: 6.9088 - val_adjusted_r2_score: 0.4541 - val_crps_metric: 5.8471 - val_loss: 7.0711 - learning_rate: 2.5000e-04
# Epoch 92/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - adjusted_r2_score: 0.4521 - crps_metric: 5.7095 - loss: 6.9331 - val_adjusted_r2_score: 0.4580 - val_crps_metric: 5.8431 - val_loss: 7.0669 - learning_rate: 2.5000e-04
# Epoch 93/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - adjusted_r2_score: 0.4548 - crps_metric: 5.7247 - loss: 6.9480 - val_adjusted_r2_score: 0.4618 - val_crps_metric: 5.8812 - val_loss: 7.1050 - learning_rate: 2.5000e-04
# Epoch 94/100
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - adjusted_r2_score: 0.4598 - crps_metric: 5.6989 - loss: 6.9221
# Epoch 94: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 7s 64ms/step - adjusted_r2_score: 0.4597 - crps_metric: 5.6988 - loss: 6.9219 - val_adjusted_r2_score: 0.4647 - val_crps_metric: 5.8546 - val_loss: 7.0780 - learning_rate: 2.5000e-04
# Epoch 95/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 9s 46ms/step - adjusted_r2_score: 0.4636 - crps_metric: 5.7116 - loss: 6.9345 - val_adjusted_r2_score: 0.4671 - val_crps_metric: 5.8703 - val_loss: 7.0936 - learning_rate: 1.2500e-04
# Epoch 96/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - adjusted_r2_score: 0.4646 - crps_metric: 5.7302 - loss: 6.9531 - val_adjusted_r2_score: 0.4689 - val_crps_metric: 5.8963 - val_loss: 7.1196 - learning_rate: 1.2500e-04
# Epoch 97/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - adjusted_r2_score: 0.4660 - crps_metric: 5.6770 - loss: 6.8997 - val_adjusted_r2_score: 0.4707 - val_crps_metric: 5.8591 - val_loss: 7.0821 - learning_rate: 1.2500e-04
# Epoch 98/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - adjusted_r2_score: 0.4689 - crps_metric: 5.6685 - loss: 6.8910 - val_adjusted_r2_score: 0.4727 - val_crps_metric: 5.8386 - val_loss: 7.0614 - learning_rate: 1.2500e-04
# Epoch 99/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - adjusted_r2_score: 0.4712 - crps_metric: 5.6649 - loss: 6.8872 - val_adjusted_r2_score: 0.4748 - val_crps_metric: 5.8920 - val_loss: 7.1148 - learning_rate: 1.2500e-04
# Epoch 100/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 10s 55ms/step - adjusted_r2_score: 0.4713 - crps_metric: 5.6929 - loss: 6.9151 - val_adjusted_r2_score: 0.4772 - val_crps_metric: 5.8652 - val_loss: 7.0878 - learning_rate: 1.2500e-04
# Restoring model weights from the end of the best epoch: 98.
# Model saved successfully.
